# %%
import numpy as np
import pandas as pd

# %%
w = np.array([4,7,9,1])
m = np.array([[3,2,4,7] , [11,6,7,2]])
print("W:",w)
print("M:",m)
print("W DIM: " , w.ndim)
print("M DIM: " , m.ndim)
print("DTYPE : " , m.dtype)
print("TYPE : ", type(m))
# Out:
# W: [4 7 9 1]
# M: [[ 3  2  4  7]
#  [11  6  7  2]]
# W DIM:  1
# M DIM:  2
# DTYPE :  int64
# TYPE :  <class 'numpy.ndarray'>

# %%
print(m)
print("=========================")
print("SHAPE : " , m.shape)
# Out:
# [[ 3  2  4  7]
#  [11  6  7  2]]
# ...
# SHAPE :  (2, 4)

# %%
m = np.array([[3,2,4,7] , [11,6,7,2]] , ndmin = 5)
print("M:",m)
print("M DIM: " , m.ndim)
# Out:
# M: [[[[[ 3  2  4  7]
#     [11  6  7  2]]]]]
# M DIM:  5

# %%
m.shape
# Out:
# (1, 1, 1, 2, 4)

# %%
m.reshape(8,1)
# Out:
# array([[ 3],
#        [ 2],
#        [ 4],
#        [ 7],
#        [11],
#        [ 6],
#        [ 7],
#        [ 2]])

# %%
m.reshape(1,8)
# Out:
# array([[ 3,  2,  4,  7, 11,  6,  7,  2]])

# %%
m.reshape(8,)
# Out:
# array([ 3,  2,  4,  7, 11,  6,  7,  2])

# %%
m.reshape(2,8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3266/3152597587.py in <cell line: 0>()
# ----> 1 m.reshape(2,8)
#
# ValueError: cannot reshape array of size 8 into shape (2,8)

# %%
print("(2,4): ",m.reshape(2,4))
print("============================")
print("(4,2): ",m.reshape(4,2))
# Out:
# (2,4):  [[ 3  2  4  7]
#  [11  6  7  2]]
# ...
# (4,2):  [[ 3  2]
#  [ 4  7]
#  [11  6]
#  [ 7  2]]

# %%
m
# Out:
# array([[[[[ 3,  2,  4,  7],
#           [11,  6,  7,  2]]]]])

# %%
import numpy as np
import pandas as pd

# %%
ty = pd.read_csv("/content/Retail_Dataset_Modified.csv")
ty
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
ty.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1   BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2     BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
# 3  BX_CHENNAI_061     BrandX_India Trends Chennai  BrandX_India    Mall Store
# 4  BX_CHENNAI_033    BrandX_India Connect Chennai  BrandX_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100g  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1kg  Groceries            Sugar
# 2     Pune     Tier1   Levi's T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    PlayStation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ... Brand_Loyalty Brand_Awareness  Price_Competitiveness  \
# ...

# %%
ty.tail()
# Out:
#            Store_ID                       Store_Name    Brand_Name  \
# 5166  BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167  BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168  BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169  BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170   BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 5166  Street Store  Jaipur      Tier2       Pepe Jeans      Clothes
# 5167       Express  Mumbai      Metro  White Sugar 1kg    Groceries
# 5168      Flagship  Kanpur      Tier2      Dell XPS 13  Electronics
# 5169  Street Store  Mumbai      Metro     Nike Air Max      Clothes
# 5170      Flagship   Delhi      Metro   MacBook Air M2  Electronics
#
#      Sub_Category Product_Stage  ... Brand_Loyalty Brand_Awareness  \
# 5166        Jeans     Declining  ...          91.3            68.7
# ...

# %%
ty.sample(5)
# Out:
#               Store_ID                          Store_Name    Brand_Name  \
# 358   BX_AHMEDABAD_021  BrandX_India Electronics Ahmedabad  BrandX_India
# 251      BX_MUMBAI_039     BrandX_India Electronics Mumbai  BrandX_India
# 717      BX_JAIPUR_069        BrandX_India Tech Hub Jaipur  BrandX_India
# 4038     BX_MUMBAI_038     BrandX_India Accessories Mumbai  BrandX_India
# 3239     BX_MUMBAI_059         BrandX_India Digital Mumbai  BrandX_India
#
#         Store_Type       City City_Tier      Product_Name     Category  \
# 358   Street Store  Ahmedabad     Tier1   Sony WH-1000XM5  Electronics
# 251        Express     Mumbai     Metro       HP Pavilion  Electronics
# 717     Online Hub     Jaipur     Tier2    Samsung Tab S8  Electronics
# 4038    Online Hub     Mumbai     Metro  Sony Alpha a7 IV      Gadgets
# 3239    Online Hub     Mumbai     Metro         iPhone 14  Electronics
#
#      Sub_Category Product_Stage  ... Brand_Loyalty Brand_Awareness  \
# ...

# %%
ty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5171 non-null   object
#  1   Store_Name             5171 non-null   object
#  2   Brand_Name             5171 non-null   object
#  3   Store_Type             5171 non-null   object
#  4   City                   5109 non-null   object
#  5   City_Tier              5171 non-null   object
#  6   Product_Name           5098 non-null   object
#  7   Category               5171 non-null   object
#  8   Sub_Category           5171 non-null   object
#  9   Product_Stage          5171 non-null   object
#  10  Quantity_Available     5171 non-null   object
#  11  Units_Sold             5171 non-null   object
#  12  Unit_Price             5171 non-null   int64
#  13  Cost_Price             5171 non-null   int64
# ...

# %%
ty.isnull().sum()
# Out:
# Store_ID                  0
# Store_Name                0
# Brand_Name                0
# Store_Type                0
# City                     62
# City_Tier                 0
# Product_Name             73
# Category                  0
# Sub_Category              0
# Product_Stage             0
# Quantity_Available        0
# Units_Sold                0
# Unit_Price                0
# Cost_Price                0
# Revenue                  72
# Profit_Margin             0
# Average_Order_Value       0
# Inventory_Turnover        0
# Days_of_Stock             0
# Customer_Segment          0
# Sales_Channel             0
# Payment_Method            0
# Supplier                 68
# Supplier_Rating           0
# Promotion_Type            0
# Promotion_Impact          0
# Max_Discount_Offered      0
# Return_Rate               0
# Return_Reason             0
# Customer_Satisfaction    77
# Online_Rating             0
# Review_Count              0
# Sales_Rep_Experience      0
# ...

# %%
ty.isnull().sum().sum()
# Out:
# np.int64(412)

# %%
ty.head(9)
# Out:
#          Store_ID                       Store_Name    Brand_Name  \
# 0     BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1   BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2     BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3  BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4  BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# 5    BX_DELHI_082    BrandX_India Superstore Delhi  BrandX_India
# 6   BX_MUMBAI_062  BrandX_India Accessories Mumbai  BrandX_India
# 7    BX_DELHI_062       BrandX_India Digital Delhi  BrandX_India
# 8   BX_MUMBAI_042   BrandX_India Appliances Mumbai  BrandX_India
#
#      Store_Type     City City_Tier     Product_Name         Category  \
# 0      Flagship     Pune     Tier1   Green Tea 100g        Groceries
# 1  Street Store   Mumbai     Metro  White Sugar 1kg        Groceries
# 2      Flagship     Pune     Tier1   Levi's T-Shirt          Clothes
# ...

# %%
ty.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
ty["City"].value_counts()
# Out:
# City
# Delhi            1031
# Mumbai            980
# Bangalore         512
# Chennai           485
# Hyderabad         470
# Pune              272
# Jaipur            268
# Ahmedabad         254
# Surat             232
# Bhopal            113
# Nagpur            111
# Visakhapatnam     106
# Kanpur             98
# Lucknow            92
# Mumbai              8
# MUMBAI              7
# Delhi               7
# delhi               6
# CHENNAI             4
# chennai             4
#   Mumbai            4
#   Chennai           3
#   Delhi             3
# Chennai             3
#   Jaipur            3
# jaipur              2
# AHMEDABAD           2
#   Kanpur            2
#   Hyderabad         2
# Jaipur              2
# mumbai              2
#   Surat             2
# KANPUR              1
# JAIPUR              1
# NAGPUR              1
# ahmedabad           1
# hyderabad           1
# bhopal              1
# HYDERABAD           1
# lucknow             1
# BANGALORE           1
# ...

# %%
ty["City_2"] = ty["City"].replace({"pune" : "Pune"})

# %%
ty.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season', 'City_2'],
#       dtype='object')

# %%
ty["City_2"].value_counts()
# Out:
# City_2
# Delhi            1031
# Mumbai            980
# Bangalore         512
# Chennai           485
# Hyderabad         470
# Pune              273
# Jaipur            268
# Ahmedabad         254
# Surat             232
# Bhopal            113
# Nagpur            111
# Visakhapatnam     106
# Kanpur             98
# Lucknow            92
# Mumbai              8
# MUMBAI              7
# Delhi               7
# delhi               6
#   Mumbai            4
# chennai             4
# CHENNAI             4
#   Chennai           3
#   Delhi             3
# Chennai             3
#   Jaipur            3
# jaipur              2
#   Kanpur            2
# AHMEDABAD           2
# mumbai              2
#   Hyderabad         2
# Jaipur              2
#   Surat             2
# KANPUR              1
# NAGPUR              1
# HYDERABAD           1
# hyderabad           1
# lucknow             1
# bhopal              1
# JAIPUR              1
# BANGALORE           1
# ahmedabad           1
# ...

# %%
ty["City_2"] = ty["City"].replace({"pune" : "Pune" , "KANPUR" : "Kanpur"})

# %%
ty["City_2"].value_counts()
# Out:
# City_2
# Delhi            1031
# Mumbai            980
# Bangalore         512
# Chennai           485
# Hyderabad         470
# Pune              273
# Jaipur            268
# Ahmedabad         254
# Surat             232
# Bhopal            113
# Nagpur            111
# Visakhapatnam     106
# Kanpur             99
# Lucknow            92
# Mumbai              8
# MUMBAI              7
# Delhi               7
# delhi               6
#   Mumbai            4
# CHENNAI             4
# chennai             4
#   Delhi             3
# Chennai             3
#   Chennai           3
#   Jaipur            3
# AHMEDABAD           2
# jaipur              2
#   Kanpur            2
#   Hyderabad         2
# mumbai              2
#   Surat             2
# Jaipur              2
# BANGALORE           1
# HYDERABAD           1
# hyderabad           1
# lucknow             1
# bhopal              1
# JAIPUR              1
# NAGPUR              1
# ahmedabad           1
#   Pune              1
# ...

# %%
for j in ty["City"]:
  print(j)
# Out:
# Pune
# Mumbai
# Pune
# Chennai
# Chennai
# Delhi
# Mumbai
# Delhi
# Mumbai
# Nagpur
# Mumbai
# Delhi
# Delhi
# Delhi
# Nagpur
# Bangalore
# Delhi
# Bangalore
# Hyderabad
# Mumbai
# Delhi
# Mumbai
# Mumbai
# Pune
# Delhi
# Chennai
# Mumbai
# nan
# Bhopal
# Visakhapatnam
# Mumbai
# Surat
# Jaipur
# Mumbai
# Mumbai
# Ahmedabad
# Bangalore
# Mumbai
# Delhi
# Mumbai
# Mumbai
# Bangalore
# Bangalore
# Bangalore
# Delhi
# Mumbai
# Surat
# Surat
# Chennai
# Jaipur
# Kanpur
# Delhi
# Mumbai
# Delhi
# Mumbai
# Mumbai
# Mumbai
# Mumbai
# Surat
# Mumbai
# Visakhapatnam
# Hyderabad
# Delhi
# Surat
# Visakhapatnam
# Mumbai
# Pune
# Bhopal
# Chennai
# Bangalore
# Bhopal
# Chennai
# Ahmedabad
# Hyderabad
# Delhi
# Chennai
# Bangalore
# Delhi
# Hyderabad
# Mumbai
# Bangalore
# Bangalore
# Hyderabad
# Mumbai
# CHENNAI
# Delhi
# Bangalore
# Bangalore
# Mumbai
# Delhi
# Mumbai
# Hyderabad
# Hyderabad
# Visakhapatnam
# Mumbai
# Mumbai
# Bangalore
# Chennai
# Pune
# Bangalore
# Mumbai
# Jaipur
# Mumbai
# ...

# %%
e = []
for j in ty["City"]:
  if j == "KANPUR" or j == "Kanpur" or j == "kanpur":
    e.append(j)
print(e)
# Out:
# ['Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'KANPUR', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur', 'Kanpur']

# %%
e.index("Kanpur")
# Out:
# 0

# %%
len(e)
# Out:
# 99

# %%
ty["City"].sort_values()
# Out:
# 1957      Chennai
# 3323      Chennai
# 913       Chennai
# 2022        Delhi
# 658         Delhi
#            ...
# 4882            NaN
# 4956            NaN
# 5059            NaN
# 5068            NaN
# 5103            NaN
# Name: City, Length: 5171, dtype: object

# %%
ty["City"].where((ty["City"] == "KANPUR") | (ty["City"] == "Kanpur"))
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 5166    NaN
# 5167    NaN
# 5168    NaN
# 5169    NaN
# 5170    NaN
# Name: City, Length: 5171, dtype: object

# %%
ty['City_cleaned'] = ty['City'].str.strip().str.capitalize()
ty_kanpur = ty[ty['City_cleaned'] == 'Kanpur']
ty_kanpur
# Out:
#            Store_ID                       Store_Name    Brand_Name  \
# 50    BX_KANPUR_045     BrandX_India Tech Hub Kanpur  BrandX_India
# 119   BX_KANPUR_004      BrandX_India Apparel Kanpur  BrandX_India
# 147   BX_KANPUR_019   BrandX_India Superstore Kanpur  BrandX_India
# 211   BX_KANPUR_059      BrandX_India Comfort Kanpur  BrandX_India
# 273   BX_KANPUR_069  BrandX_India Accessories Kanpur  BrandX_India
# ...             ...                              ...           ...
# 4946  BX_KANPUR_055       BrandX_India Living Kanpur  BrandX_India
# 5017  BX_KANPUR_055  BrandX_India Electronics Kanpur  BrandX_India
# 5066  BX_KANPUR_038      BrandX_India Express Kanpur  BrandX_India
# 5163  BX_KANPUR_030      BrandX_India Digital Kanpur  BrandX_India
# 5168  BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
#
#       Store_Type     City City_Tier        Product_Name         Category  \
# 50      Flagship   Kanpur     Tier2            iPad Pro      Electronics
# ...

# %%
ty.head(9)
# Out:
#          Store_ID                       Store_Name    Brand_Name  \
# 0     BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1   BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2     BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3  BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4  BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# 5    BX_DELHI_082    BrandX_India Superstore Delhi  BrandX_India
# 6   BX_MUMBAI_062  BrandX_India Accessories Mumbai  BrandX_India
# 7    BX_DELHI_062       BrandX_India Digital Delhi  BrandX_India
# 8   BX_MUMBAI_042   BrandX_India Appliances Mumbai  BrandX_India
#
#      Store_Type     City City_Tier     Product_Name         Category  \
# 0      Flagship     Pune     Tier1   Green Tea 100g        Groceries
# 1  Street Store   Mumbai     Metro  White Sugar 1kg        Groceries
# 2      Flagship     Pune     Tier1   Levi's T-Shirt          Clothes
# ...

# %%
ty[ty["Store_Type"] == "Flagship"]
# Out:
#            Store_ID                       Store_Name    Brand_Name Store_Type  \
# 0       BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India   Flagship
# 2       BX_PUNE_073         BrandX_India Trends Pune  BrandX_India   Flagship
# 21    BX_MUMBAI_088      BrandX_India Express Mumbai  BrandX_India   Flagship
# 23      BX_PUNE_051        BrandX_India Fashion Pune  BrandX_India   Flagship
# 24     BX_DELHI_061          BrandX_India Home Delhi  BrandX_India   Flagship
# ...             ...                              ...           ...        ...
# 5149   BX_DELHI_054         BrandX_India Style Delhi  BrandX_India   Flagship
# 5160  BX_MUMBAI_019   BrandX_India Superstore Mumbai  BrandX_India   Flagship
# 5161  BX_JAIPUR_075      BrandX_India Fashion Jaipur  BrandX_India   Flagship
# 5168  BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India   Flagship
# 5170   BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India   Flagship
#
# ...

# %%
len(ty[ty["Store_Type"] == "Flagship"])
# Out:
# 1055

# %%
ty[(ty["Store_Type"] == "Flagship") & (ty["City"] == "Mumbai")]
# Out:
#            Store_ID                       Store_Name    Brand_Name Store_Type  \
# 21    BX_MUMBAI_088      BrandX_India Express Mumbai  BrandX_India   Flagship
# 26    BX_MUMBAI_019       BrandX_India Mobile Mumbai  BrandX_India   Flagship
# 30    BX_MUMBAI_020     BrandX_India Tech Hub Mumbai  BrandX_India   Flagship
# 37    BX_MUMBAI_092  BrandX_India Accessories Mumbai  BrandX_India   Flagship
# 39    BX_MUMBAI_068  BrandX_India Electronics Mumbai  BrandX_India   Flagship
# ...             ...                              ...           ...        ...
# 5034  BX_MUMBAI_041  BrandX_India Gadget Zone Mumbai  BrandX_India   Flagship
# 5106  BX_MUMBAI_033       BrandX_India Trends Mumbai  BrandX_India   Flagship
# 5113  BX_MUMBAI_003      BrandX_India Connect Mumbai  BrandX_India   Flagship
# 5126  BX_MUMBAI_086        BrandX_India Fresh Mumbai  BrandX_India   Flagship
# 5133  BX_MUMBAI_066   BrandX_India Appliances Mumbai  BrandX_India   Flagship
#
# ...

# %%
ty
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
ty[ty.duplicated()]
# Out:
#               Store_ID                          Store_Name    Brand_Name  \
# 5121  BX_BANGALORE_099      BrandX_India Apparel Bangalore  BrandX_India
# 5122     BX_MUMBAI_095          BrandX_India Trends Mumbai  BrandX_India
# 5123  BX_BANGALORE_058      BrandX_India Digital Bangalore  BrandX_India
# 5124      BX_DELHI_027           BrandX_India Trends Delhi  BrandX_India
# 5125  BX_BANGALORE_062        BrandX_India Daily Bangalore  BrandX_India
# 5126     BX_MUMBAI_086           BrandX_India Fresh Mumbai  BrandX_India
# 5127  BX_BANGALORE_097   BrandX_India Superstore Bangalore  BrandX_India
# 5128    BX_CHENNAI_053          BrandX_India Daily Chennai  BrandX_India
# 5129  BX_BANGALORE_082  BrandX_India Accessories Bangalore  BrandX_India
# 5130      BX_DELHI_079            BrandX_India Smart Delhi  BrandX_India
# 5131      BX_SURAT_090          BrandX_India Apparel Surat  BrandX_India
# 5132      BX_DELHI_007          BrandX_India Comfort Delhi  BrandX_India
# ...

# %%
ty[ty["City_Tier"].duplicated()]
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# 5       BX_DELHI_082    BrandX_India Superstore Delhi  BrandX_India
# 6      BX_MUMBAI_062  BrandX_India Accessories Mumbai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 2         Flagship     Pune     Tier1   Levi's T-Shirt      Clothes
# ...
