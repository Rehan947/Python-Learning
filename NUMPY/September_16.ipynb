# %%
import numpy as np
import pandas as pd

# %%
nm = pd.read_csv("/content/Retail_Dataset_Modified.csv")
nm
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
name = ["Sneh","Bhavya","Parth","Rehan","Uzair"]
pin = [104,102,106,109,110]
city = ["AHMEDABAD","SURAT","PUNE","NASHIK","PUNE"]

# %%
nm2 = {"NAME" : name , "PIN" : pin , "CITY" : city}
nm2
# Out:
# {'NAME': ['Sneh', 'Bhavya', 'Parth', 'Rehan', 'Uzair'],
#  'PIN': [104, 102, 106, 109, 110],
#  'CITY': ['AHMEDABAD', 'SURAT', 'PUNE', 'NASHIK', 'PUNE']}

# %%
nm5 = pd.DataFrame(nm2)
nm5
# Out:
#      NAME  PIN       CITY
# 0    Sneh  104  AHMEDABAD
# 1  Bhavya  102      SURAT
# 2   Parth  106       PUNE
# 3   Rehan  109     NASHIK
# 4   Uzair  110       PUNE

# %%
type(nm5)
# Out:
# pandas.core.frame.DataFrame

# %%
type(nm5["NAME"])
nm5["NAME"].ndim
# Out:
# 1

# %%
nm5.ndim
# Out:
# 2

# %%
nm5.head()
# Out:
#      NAME  PIN       CITY
# 0    Sneh  104  AHMEDABAD
# 1  Bhavya  102      SURAT
# 2   Parth  106       PUNE
# 3   Rehan  109     NASHIK
# 4   Uzair  110       PUNE

# %%
nm.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1   BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2     BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
# 3  BX_CHENNAI_061     BrandX_India Trends Chennai  BrandX_India    Mall Store
# 4  BX_CHENNAI_033    BrandX_India Connect Chennai  BrandX_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100g  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1kg  Groceries            Sugar
# 2     Pune     Tier1   Levi's T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    PlayStation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ... Brand_Loyalty Brand_Awareness  Price_Competitiveness  \
# ...

# %%
nm.tail()
# Out:
#            Store_ID                       Store_Name    Brand_Name  \
# 5166  BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167  BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168  BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169  BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170   BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 5166  Street Store  Jaipur      Tier2       Pepe Jeans      Clothes
# 5167       Express  Mumbai      Metro  White Sugar 1kg    Groceries
# 5168      Flagship  Kanpur      Tier2      Dell XPS 13  Electronics
# 5169  Street Store  Mumbai      Metro     Nike Air Max      Clothes
# 5170      Flagship   Delhi      Metro   MacBook Air M2  Electronics
#
#      Sub_Category Product_Stage  ... Brand_Loyalty Brand_Awareness  \
# 5166        Jeans     Declining  ...          91.3            68.7
# ...

# %%
nm.sample(7)
# Out:
#               Store_ID                         Store_Name    Brand_Name  \
# 3896  BX_BANGALORE_088  BrandX_India Superstore Bangalore  BrandX_India
# 1400  BX_HYDERABAD_011     BrandX_India Apparel Hyderabad  BrandX_India
# 1599    BX_CHENNAI_058         BrandX_India Daily Chennai  BrandX_India
# 1780    BX_LUCKNOW_022      BrandX_India Tech Hub Lucknow  BrandX_India
# 2282  BX_BANGALORE_056     BrandX_India Apparel Bangalore  BrandX_India
# 1445  BX_BANGALORE_008     BrandX_India Comfort Bangalore  BrandX_India
# 3121     BX_MUMBAI_071          BrandX_India Style Mumbai  BrandX_India
#
#         Store_Type       City City_Tier        Product_Name         Category  \
# 3896       Express  Bangalore     Metro     White Sugar 1kg        Groceries
# 1400      Flagship  Hyderabad     Metro  Zara Evening Dress          Clothes
# 1599       Express    Chennai     Metro      Brown Rice 1kg        Groceries
# 1780       Express    Lucknow     Tier2          OnePlus 11      Electronics
# ...

# %%
nm5.columns
# Out:
# Index(['NAME', 'PIN', 'CITY'], dtype='object')

# %%
nm.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
len(nm.columns)
# Out:
# 47

# %%
nm5.isnull()
# Out:
#     NAME    PIN   CITY
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False

# %%
nm5.isnull().sum()
# Out:
# NAME    0
# PIN     0
# CITY    0
# dtype: int64

# %%
nm.isnull()
# Out:
#       Store_ID  Store_Name  Brand_Name  Store_Type   City  City_Tier  \
# 0        False       False       False       False  False      False
# 1        False       False       False       False  False      False
# 2        False       False       False       False  False      False
# 3        False       False       False       False  False      False
# 4        False       False       False       False  False      False
# ...        ...         ...         ...         ...    ...        ...
# 5166     False       False       False       False  False      False
# 5167     False       False       False       False  False      False
# 5168     False       False       False       False  False      False
# 5169     False       False       False       False  False      False
# 5170     False       False       False       False  False      False
#
#       Product_Name  Category  Sub_Category  Product_Stage  ...  Brand_Loyalty  \
# ...

# %%
nm.isnull().sum()
# Out:
# Store_ID                  0
# Store_Name                0
# Brand_Name                0
# Store_Type                0
# City                     62
# City_Tier                 0
# Product_Name             73
# Category                  0
# Sub_Category              0
# Product_Stage             0
# Quantity_Available        0
# Units_Sold                0
# Unit_Price                0
# Cost_Price                0
# Revenue                  72
# Profit_Margin             0
# Average_Order_Value       0
# Inventory_Turnover        0
# Days_of_Stock             0
# Customer_Segment          0
# Sales_Channel             0
# Payment_Method            0
# Supplier                 68
# Supplier_Rating           0
# Promotion_Type            0
# Promotion_Impact          0
# Max_Discount_Offered      0
# Return_Rate               0
# Return_Reason             0
# Customer_Satisfaction    77
# Online_Rating             0
# Review_Count              0
# Sales_Rep_Experience      0
# ...

# %%
nm.isnull().sum() > 1
# Out:
# Store_ID                 False
# Store_Name               False
# Brand_Name               False
# Store_Type               False
# City                      True
# City_Tier                False
# Product_Name              True
# Category                 False
# Sub_Category             False
# Product_Stage            False
# Quantity_Available       False
# Units_Sold               False
# Unit_Price               False
# Cost_Price               False
# Revenue                   True
# Profit_Margin            False
# Average_Order_Value      False
# Inventory_Turnover       False
# Days_of_Stock            False
# Customer_Segment         False
# Sales_Channel            False
# Payment_Method           False
# Supplier                  True
# Supplier_Rating          False
# Promotion_Type           False
# Promotion_Impact         False
# Max_Discount_Offered     False
# Return_Rate              False
# Return_Reason            False
# Customer_Satisfaction     True
# ...

# %%
nm.loc[:, nm.isnull().sum() > 1]
# Out:
#          City     Product_Name  Revenue                     Supplier  \
# 0        Pune   Green Tea 100g     7320  BrandX_India E-commerce Hub
# 1      Mumbai  White Sugar 1kg     1645   BrandX_India Direct Import
# 2        Pune   Levi's T-Shirt    66340  BrandX_India Local Sourcing
# 3     Chennai    Adidas Hoodie    77748   BrandX_India Direct Import
# 4     Chennai    PlayStation 5  1976364  BrandX_India Local Sourcing
# ...       ...              ...      ...                          ...
# 5166  Jaipur        Pepe Jeans    16611  BRANDX_INDIA LOCAL SOURCING
# 5167  Mumbai   White Sugar 1kg     2808  BRANDX_INDIA LOCAL SOURCING
# 5168  Kanpur       Dell XPS 13   982202  BRANDX_INDIA E-COMMERCE HUB
# 5169  Mumbai      Nike Air Max   244244   BRANDX_INDIA DIRECT IMPORT
# 5170   Delhi    MacBook Air M2  1408680  BRANDX_INDIA LOCAL SOURCING
#
#       Customer_Satisfaction  Delivery_Time
# 0                       4.0            6.0
# 1                       3.9            4.0
# ...

# %%
nm.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
nm.loc[: , ['Brand_Name', 'City']]
# Out:
#         Brand_Name     City
# 0     BrandX_India     Pune
# 1     BrandX_India   Mumbai
# 2     BrandX_India     Pune
# 3     BrandX_India  Chennai
# 4     BrandX_India  Chennai
# ...            ...      ...
# 5166  BrandX_India  Jaipur
# 5167  BrandX_India  Mumbai
# 5168  BrandX_India  Kanpur
# 5169  BrandX_India  Mumbai
# 5170  BrandX_India   Delhi
#
# [5171 rows x 2 columns]

# %%
nm.loc[3 , : ]
# Out:
# Store_ID                              BX_CHENNAI_061
# Store_Name               BrandX_India Trends Chennai
# Brand_Name                              BrandX_India
# Store_Type                                Mall Store
# City                                         Chennai
# City_Tier                                      Metro
# Product_Name                           Adidas Hoodie
# Category                                     Clothes
# Sub_Category                                 Jackets
# Product_Stage                             New Launch
# Quantity_Available                               163
# Units_Sold                                        22
# Unit_Price                                      3534
# Cost_Price                                      2894
# Revenue                                        77748
# Profit_Margin                                  18.11
# Average_Order_Value                             4416
# Inventory_Turnover                              1.62
# ...

# %%
nm.loc[[3,7,9,1] , ['Online_Rating', 'Review_Count', 'Sales_Rep_Experience']]
# Out:
#    Online_Rating  Review_Count  Sales_Rep_Experience
# 3            5.0           221                     7
# 7            4.6           282                     6
# 9            4.7           222                     2
# 1            4.4           202                    10

# %%
nm.iloc[[5,7,1,3,17,19,35] , [3,8,5,1]]
# Out:
#       Store_Type Sub_Category City_Tier                      Store_Name
# 5   Street Store          Dal     Metro   BrandX_India Superstore Delhi
# 7     Mall Store      Laptops     Metro      BrandX_India Digital Delhi
# 1   Street Store        Sugar     Metro  BrandX_India Superstore Mumbai
# 3     Mall Store      Jackets     Metro     BrandX_India Trends Chennai
# 17    Mall Store          Oil     Metro    BrandX_India Daily Bangalore
# 19    Mall Store        Jeans     Metro       BrandX_India Style Mumbai
# 35      Flagship          Dal     Tier1    BrandX_India Daily Ahmedabad

# %%
nm.isnull().sum()
# Out:
# Store_ID                  0
# Store_Name                0
# Brand_Name                0
# Store_Type                0
# City                     62
# City_Tier                 0
# Product_Name             73
# Category                  0
# Sub_Category              0
# Product_Stage             0
# Quantity_Available        0
# Units_Sold                0
# Unit_Price                0
# Cost_Price                0
# Revenue                  72
# Profit_Margin             0
# Average_Order_Value       0
# Inventory_Turnover        0
# Days_of_Stock             0
# Customer_Segment          0
# Sales_Channel             0
# Payment_Method            0
# Supplier                 68
# Supplier_Rating           0
# Promotion_Type            0
# Promotion_Impact          0
# Max_Discount_Offered      0
# Return_Rate               0
# Return_Reason             0
# Customer_Satisfaction    77
# Online_Rating             0
# Review_Count              0
# Sales_Rep_Experience      0
# ...

# %%
nm.loc[: , nm.isnull().sum() > 1 ].columns
# Out:
# Index(['City', 'Product_Name', 'Revenue', 'Supplier', 'Customer_Satisfaction',
#        'Delivery_Time'],
#       dtype='object')

# %%
nm.loc[: , nm.isnull().sum() == 68 ].columns
# Out:
# Index(['Supplier'], dtype='object')

# %%
nm.isnull().sum()
# Out:
# Store_ID                  0
# Store_Name                0
# Brand_Name                0
# Store_Type                0
# City                     62
# City_Tier                 0
# Product_Name             73
# Category                  0
# Sub_Category              0
# Product_Stage             0
# Quantity_Available        0
# Units_Sold                0
# Unit_Price                0
# Cost_Price                0
# Revenue                  72
# Profit_Margin             0
# Average_Order_Value       0
# Inventory_Turnover        0
# Days_of_Stock             0
# Customer_Segment          0
# Sales_Channel             0
# Payment_Method            0
# Supplier                 68
# Supplier_Rating           0
# Promotion_Type            0
# Promotion_Impact          0
# Max_Discount_Offered      0
# Return_Rate               0
# Return_Reason             0
# Customer_Satisfaction    77
# Online_Rating             0
# Review_Count              0
# Sales_Rep_Experience      0
# ...

# %%
nm.shape
# Out:
# (5171, 47)

# %%
nm.dropna(inplace = True)

# %%
nm.shape
# Out:
# (4759, 47)

# %%
name2 = ["Sneh","Bhavya","","Parth","Rehan","Uzair"]
pin2 = [104,102,106,109,"",110]
city2 = ["AHMEDABAD","SURAT","PUNE","NASHIK","PUNE",""]

# %%
gh = pd.DataFrame({"NAME" : name2 , "PIN" : pin2 , "CITY" : city2})
gh
# Out:
#      NAME  PIN       CITY
# 0    Sneh  104  AHMEDABAD
# 1  Bhavya  102      SURAT
# 2          106       PUNE
# 3   Parth  109     NASHIK
# 4   Rehan            PUNE
# 5   Uzair  110

# %%
gh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    6 non-null      object
#  1   PIN     6 non-null      object
#  2   CITY    6 non-null      object
# dtypes: object(3)
# memory usage: 276.0+ bytes

# %%
gh.isnull().sum()
# Out:
# NAME    0
# PIN     0
# CITY    0
# dtype: int64

# %%
name2 = ["Sneh","Bhavya",np.nan,"Parth","Rehan","Uzair"]
pin2 = [104,102,106,109,np.nan,110]
city2 = ["AHMEDABAD","SURAT","PUNE","NASHIK","PUNE",np.nan]

# %%
wr = pd.DataFrame({"NAME" : name2 , "PIN" : pin2 , "CITY" : city2})
wr
# Out:
#      NAME    PIN       CITY
# 0    Sneh  104.0  AHMEDABAD
# 1  Bhavya  102.0      SURAT
# 2     NaN  106.0       PUNE
# 3   Parth  109.0     NASHIK
# 4   Rehan    NaN       PUNE
# 5   Uzair  110.0        NaN

# %%
wr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    5 non-null      object
#  1   PIN     5 non-null      float64
#  2   CITY    5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 276.0+ bytes

# %%
wr.isnull().sum()
# Out:
# NAME    1
# PIN     1
# CITY    1
# dtype: int64

# %%
wr.describe()
# Out:
#              PIN
# count    5.00000
# mean   106.20000
# std      3.34664
# min    102.00000
# 25%    104.00000
# 50%    106.00000
# 75%    109.00000
# max    110.00000

# %%
wr.columns
# Out:
# Index(['NAME', 'PIN', 'CITY'], dtype='object')

# %%
wr["PIN"].mean()
# Out:
# np.float64(106.2)

# %%
wr["PIN"].median()
# Out:
# 106.0

# %%
wr
# Out:
#      NAME    PIN       CITY
# 0    Sneh  104.0  AHMEDABAD
# 1  Bhavya  102.0      SURAT
# 2     NaN  106.0       PUNE
# 3   Parth  109.0     NASHIK
# 4   Rehan    NaN       PUNE
# 5   Uzair  110.0        NaN

# %%
wr["PIN"].fillna(wr["PIN"].mean())
# Out:
# 0    104.0
# 1    102.0
# 2    106.0
# 3    109.0
# 4    106.2
# 5    110.0
# Name: PIN, dtype: float64

# %%
wr["PIN"].fillna(wr["PIN"].median())
# Out:
# 0    104.0
# 1    102.0
# 2    106.0
# 3    109.0
# 4    106.0
# 5    110.0
# Name: PIN, dtype: float64
