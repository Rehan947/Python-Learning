# %% [markdown]
# # Operators
#
# ### Assignment/Comparision Operator

# %%
t = 7
print(t > 10)
# Out:
# False

# %%
type(t > 10)
# Out:
# bool

# %%
t = 7
print(t < 10)
# Out:
# True

# %%
print(t == 8)
# Out:
# False

# %%
print(t != 8)
# Out:
# True

# %% [markdown]
# ### Logical Operator

# %%
m = input("Enter your number : " )
print(m)
print(type(m))
print(m + 2)
# Out:
# Enter your number :  2
# 2
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 4
#       2 print(m)
#       3 print(type(m))
# ----> 4 print(m + 2)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### TYPE CASTING

# %%
g = "2"
t = int(g)
print("T:",t)
print("Type:", type(t))
# Out:
# T: 2
# Type: <class 'int'>

# %%
w = input("Enter a value for w  : ")
print(w)
print(type(w))
print("========================================")
w2 = int(input("numberr:"))
print(w2)
print(type(w2))
# Out:
# Enter a value for w  :  5
# 5
# <class 'str'>
# ...
# numberr: 5
# 5
# <class 'int'>

# %%
n2 = int(input("Enter your num : "))
print(n2 > 10 and n2 == 11)
print("*********************************************")
n2 = int(input("Enter your num : "))
print(not(n2 > 10 and n2 == 11))
# Out:
# Enter your num :  11
# True
# *********************************************
# Enter your num :  11
# False

# %%
n2 = int(input("Enter your num : "))
print(n2 > 10 or n2 == 11)
print("*********************************************")
n2 = int(input("Enter your num : "))
print(not(n2 > 10 or n2 == 11))
# Out:
# Enter your num :  11
# True
# *********************************************
# Enter your num :  11
# False

# %%
n2
# Out:
# 11

# %%
n2 + 2
# Out:
# 13

# %%
n2
# Out:
# 11

# %%
n2 = n2 + 2
print(n2)
# Out:
# 13

# %%
n2
# Out:
# 13

# %%
n2 += 2       # INCREMENT
print(n2)
# Out:
# 15

# %%
n2
# Out:
# 15

# %%
print(n2)
print()
n2 -= 4       # DECREMENT
n2
# Out:
# 15
# 11

# %%
n2
# Out:
# 11

# %% [markdown]
# ### Membership Operator

# %%
"y" in "python"
# Out:
# True

# %%
"Y" in "python"
# Out:
# False

# %%
"y" not in "python"
# Out:
# False

# %%
"Y" not in "python"
# Out:
# True

# %%
d3 = "PYTHON"
if "N" in d3: 
    print("Yes, N is here !!!!!")
# Out:
# Yes, N is here !!!!!

# %%
d3 = "PYTHON"
if "N" in d3:
    print("Yes, N is here !!!!!")
else :
    print("NO, It's not there.......")
# Out:
# Yes, N is here !!!!!

# %%
d3 = "PYTHON"
if "n" in d3:
    print("Yes, n is here !!!!!")
else :
    print("NO, It's not there.......")
# Out:
# NO, It's not there.......

# %%
g = 9
print("g:",g)
print("type g:" , type(g))

d = g
print(d)
print(type(d))
# Out:
# g: 9
# type g: <class 'int'>
# 9
# <class 'int'>

# %%
g is d
# Out:
# True

# %%
g is not d
# Out:
# False

# %%
d is g
# Out:
# True

# %%
d is not g
# Out:
# False

# %%
q = 8
m = 5
e = 2
v = 5
print("ID Q : " , id(q))
print("ID M : " , id(m))
print("ID E : " , id(e))
print("ID V : " , id(v))
# Out:
# ID Q :  140709659587720
# ID M :  140709659587624
# ID E :  140709659587528
# ID V :  140709659587624

# %%
marks = 78
if marks >= 90:
    print("GRADE A")
elif marks >= 80 :
    print("GRADE B")
elif marks >= 70:
    print("GRADE C")
elif marks >= 60:
    print("Grade D")
elif marks >= 50:
    print("PASS CLASS")
else :
    print("FAIL")
# Out:
# GRADE C

# %%
marks = int(input("Enter Your Marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 80 :
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 50:
    print("PASS CLASS")
else :
    print("FAIL")
# Out:
# Enter Your Marks:  55
# PASS CLASS

# %%
marks = int(input("Enter your marks : "))
if marks >= 70 and marks <= 79 :
    print("Class D")
elif marks >= 90 and marks <= 100 :
    print("Class A")
elif marks >= 35 and marks <= 50:
    print("PASS")
else:
    print("NOT ACCEPTED")
# Out:
# Enter your marks :  56
# NOT ACCEPTED
