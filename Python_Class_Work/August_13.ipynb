# %%
nu = 4
for t in range(1,nu+1):
    nu = nu*t
print(nu)
# Out:
# 96

# %%
5*

# %%
nu = 4
for t in range(1,nu+1):
    print(t)
# Out:
# 1
# 2
# 3
# 4

# %%
1*4
# Out:
# 4

# %%
2*4
# Out:
# 8

# %%
3*8
# Out:
# 24

# %%
4*24
# Out:
# 96

# %%
# FACTORIAL PROGRAM
nu = 5
g = 1
for t in range(1,nu+1):
    g = g*t
print(g)
# Out:
# 120

# %%
5*4*3*2

# %%
name = input("Enter your Name : ")
print(name)
# Out:
# Enter your Name :  python program
# python program

# %%
print("Title : ",name.title())
print()
print("Capitalize : " ,name.capitalize())
print()
print("UPPER :",name.upper())
# Out:
# Title :  Python Program
#
# Capitalize :  Python program
#
# UPPER : PYTHON PROGRAM

# %%
r = name.title()
print(r)
print(len(r))
print("=========================")
r[13]
# Out:
# Python Program
# 14
# ...
# 'm'

# %%
t = "Hello, good Morning"
print(t)
print()
t[2]     # Indexing
# Out:
# Hello, good Morning
# 'l'

# %%
t.find("g")
# Out:
# 7

# %%
t.find("M")
# Out:
# 12

# %%
t[12:]     # Slicing
# Out:
# 'Morning'

# %%
len(t)
# Out:
# 19

# %%
t[-7:]
# Out:
# 'Morning'

# %%
t[-7:-1]
# Out:
# 'Mornin'

# %%
t
# Out:
# 'Hello, good Morning'

# %%
len(t)
# Out:
# 19

# %%
k = t[-20:]
k
# Out:
# 'Hello, good Morning'

# %%
t[-19]
# Out:
# 'H'

# %%
t
# Out:
# 'Hello, good Morning'

# %%
t[::-1]
# Out:
# 'gninroM doog ,olleH'

# %%
t[::2]
# Out:
# 'Hlo odMrig'

# %%
t[::-2]
# Out:
# 'girMdo olH'

# %%
fname = input("Enter your fname : ")
print(fname)
print(len(fname))
# Out:
# Enter your fname :      python code
#     python code
# 15

# %%
fname = input("Enter your fname : ")
print("with strip : ",fname.strip())
print("without :",len(fname))
print("LENGTH OF LETTERS :",len(fname.strip()))
# Out:
# Enter your fname :          CODE
# with strip :  CODE
# without : 12
# LENGTH OF LETTERS : 4

# %%
fname = input("Enter your fname : ")
fname
# Out:
# Enter your fname :  This is python code
# 'This is python code'

# %%
fname = input("Enter your fname : ")
print(fname.split(" "))
# Out:
# Enter your fname :  this is python code
# ['this', 'is', 'python', 'code']

# %%
fname = input("Enter your fname : ")
print(fname.partition(" "))
# Out:
# Enter your fname :  this is python code
# ('this', ' ', 'is python code')

# %%
fname = input("Enter your fname : ")
f3 = fname.split("i")
f3
# Out:
# Enter your fname :  this is sql
# ['th', 's ', 's sql']

# %%
f3[0]
# Out:
# 'this'

# %%
f3[1]
# Out:
# 'is'

# %%
f3[2]
# Out:
# 'sql'

# %%
fname = input("Enter your fname : ")
f8 = fname.partition("i")
f8
# Out:
# Enter your fname :  this is python code
# ('th', 'i', 's is python code')
