# %%
tr_name = "Rajdhani"
tr_number = 1234568
source_station = "Ahmedabad"
destination_station = "Mumbai"
Ticket_pr = 2900.34

# %%
print("tr_name:",tr_name)
print("tr_number:",tr_number)
print("source_station:",source_station)
print("destination_station:",destination_station)
print("Ticket_pr:",Ticket_pr)
# Out:
# tr_name: Rajdhani
# tr_number: 1234568
# source_station: Ahmedabad
# destination_station: Mumbai
# Ticket_pr: 2900.34

# %%
print("tr_name:",type(tr_name))
print("tr_number:",type(tr_number))
print("source_station:",type(source_station))
print("destination_station:",type(destination_station))
print("Ticket_pr:",type(Ticket_pr))
# Out:
# tr_name: <class 'str'>
# tr_number: <class 'int'>
# source_station: <class 'str'>
# destination_station: <class 'str'>
# Ticket_pr: <class 'float'>

# %%
print(" type casting of Ticket_pr:",int(Ticket_pr))
# Out:
#  type casting of Ticket_pr: 2900

# %%
print("add more amount the payment Ticket_pr:",int(Ticket_pr) + 20)
# Out:
# add more amount the payment Ticket_pr: 2920

# %%
int(Ticket_pr)
# Out:
# 2900

# %%
Ticket_pr = Ticket_pr+20
int(Ticket_pr)
# Out:
# 2960

# %%
print("add more amount the payment Ticket_pr:",int(Ticket_pr) - 20)
# Out:
# add more amount the payment Ticket_pr: 2940

# %%
int(Ticket_pr)
# Out:
# 2960

# %%
name , age , price , city = "abcd" , 20 , 300.78 , "Ahmedabad"
print("Name : " , name)
print()
print("Age : " , age)
print()
print("Price : " , price)
# Out:
# Name :  abcd
#
# Age :  20
#
# Price :  300.78

# %%
name = age  = price = 200

# %%
name
# Out:
# 200

# %%
age
# Out:
# 200

# %%
price
# Out:
# 200

# %%
name is age
# Out:
# True

# %%
name is not age
# Out:
# False

# %%
tr_name = "Vande Bharat"
print(tr_name)
available_seats = 10
while available_seats > 0 :
    print("Your Seat Number is " , available_seats)
    available_seats -= 1
else:
    print("All booked")
# Out:
# Vande Bharat
# Your Seat Number is  10
# Your Seat Number is  9
# Your Seat Number is  8
# Your Seat Number is  7
# Your Seat Number is  6
# Your Seat Number is  5
# Your Seat Number is  4
# Your Seat Number is  3
# Your Seat Number is  2
# Your Seat Number is  1
# All booked

# %%
seats = 6
for t in range(1,10):
    if t < seats+1:
        print("your seat number is :",t)
# Out:
# your seat number is : 1
# your seat number is : 2
# your seat number is : 3
# your seat number is : 4
# your seat number is : 5
# your seat number is : 6

# %%
seats = 6
for t in range(1,10):
    if t > seats+1:
        print("your seat number is :",t)
        break
    if t == 5:
        print("Speacial Seat : " , t)
# Out:
# Speacial Seat :  5
# your seat number is : 8

# %%
h = input("Enter your name : ")
print(h)
print(h.upper())
# Out:
# Enter your name :  python
# python
# PYTHON

# %%
h = input("Enter your name : ").upper()
print(h)
# Out:
# Enter your name :  okk python
# OKK PYTHON

# %%
h = input("Enter your name : ").title()
print(h)
# Out:
# Enter your name :  okk python
# Okk Python

# %%
name2 = input("Enter your name")
age = int(input("Enter your age "))
if age > 0 and age < 101:
    print(age)
else :
    print("This is not valid age")
    age = int(input("Enter your age "))
    if age > 0 and age < 101:
        print(age)
mobile = input("Enter your mobile number : ")
if len(mobile) == 10 and mobile.isdigit() == True:
    print(mobile)
else:
    print("Mobile number not valid")
# Out:
# Enter your name ghjk
# Enter your age  56
# 56
# Enter your mobile number :  12345r6789
# Mobile number not valid
