# %%
na = input("Enter ur name : ")
na
# Out:
# Enter ur name :  This is Python cOde
# 'This is Python cOde'

# %%
na.upper()
# Out:
# 'THIS IS PYTHON CODE'

# %%
na.lower()
# Out:
# 'this is python code'

# %%
na.capitalize()
# Out:
# 'This is python code'

# %%
na.title()
# Out:
# 'This Is Python Code'

# %%
na
# Out:
# 'This is Python cOde'

# %%
na.startswith("T")
# Out:
# True

# %%
na.endswith(".")
# Out:
# False

# %%
fg = input("Enter ur name : ")
fg
# Out:
# Enter ur name :       ghjk    nmb
# '     ghjk    nmb'

# %%
len(fg)
# Out:
# 16

# %%
w = fg.strip()
print(w)
print(len(w))
# Out:
# ghjk    nmb
# 11

# %%
g = "        okk        "
print("*****",g,"*****")
print()
print("*****",g.rstrip(),"*****")
# Out:
# *****         okk         *****
#
# *****         okk *****

# %%
print("*****",g.lstrip(),"*****")
# Out:
# ***** okk         *****

# %%
m = "1234560789"
m.isdigit()
# Out:
# True

# %%
m2 = "1234560789"
m2.isdigit()
# Out:
# True

# %%
m = "1234567899"
m.isnumeric()
# Out:
# True

# %%
m = "12345 67899"
m.isnumeric()
# Out:
# False

# %%
r = "abcde"
print(r.isalpha())
# Out:
# True

# %%
username = "we1234"
print(username.isalnum())
# Out:
# True

# %%
username = "we.1234"
print(username.isalnum())
# Out:
# False

# %%
username = "we 1234"
print(username.isalnum())
# Out:
# False

# %%
full_name = input("Enter ur fullname :")
print(full_name)
e = full_name.split(" ")
e
# Out:
# Enter ur fullname : KHushBU BIRhade
# KHushBU BIRhade
# ['KHushBU', 'BIRhade']

# %%
e[0]
# Out:
# 'KHushBU'

# %%
e[1]
# Out:
# 'BIRhade'

# %%
full_name
# Out:
# 'KHushBU BIRhade'

# %%
len(full_name)     # indexing starts with 0 and , length starts with 1
# Out:
# 15

# %%
print(full_name[-12:-8])
# Out:
# shBU

# %%
full_name.find("S")
# Out:
# -1

# %%
full_name[3:7]
# Out:
# 'shBU'

# %%
print(full_name[-12:-8 :2])     # (start:stop:step)
# Out:
# sB

# %%
full_name.replace("KHUSHBU","khushbu")
# Out:
# 'KHushBU BIRhade'

# %%
age = 27 
name = "python code"
print("Hello my name is and my age is ")
# Out:
# Hello my name is and my age is

# %%
print("Hello my name is ",name,"and my age is ",age)
# Out:
# Hello my name is  python code and my age is  27

# %%
h = "Hello my name is ",name,"and my age is ",age
print(h)
# Out:
# ('Hello my name is ', 'python code', 'and my age is ', 27)

# %%
h = f"Hello my name is {name},and my age is {age}"
print(h)
# Out:
# Hello my name is python code,and my age is 27

# %%
h = "Hello my name is {},and my age is {}"
print(h.format(name,age))
# Out:
# Hello my name is python code,and my age is 27

# %%
h = "Hello my name is {},and my age is {}"
print(h.format(age,name))
# Out:
# Hello my name is 27,and my age is python code

# %%
h = "Hello my name is {1},and my age is {0}"
print(h.format(age,name))
# Out:
# Hello my name is python code,and my age is 27

# %%
h
# Out:
# 'Hello my name is {1},and my age is {0}'

# %%
h.count("e")
# Out:
# 3

# %%
h.find("o")
# Out:
# 4

# %%
print(h.find("E"))
print("OKK DONE")
# Out:
# -1
# OKK DONE

# %%
print(h.index("E"))
print("OKK DONE")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 print(h.index("E"))
#       2 print("OKK DONE")
#
# ValueError: substring not found

# %%
string2 = "This is python code"
sub2string = "python"
print(string2.find(sub2string))
# Out:
# 8

# %%
string2 = "This is python code"
sub2string = "PYthon"
print(string2.find(sub2string))
# Out:
# -1

# %%
string2 = "This is python code"
sub2string = "python"
print(string2.index(sub2string))
# Out:
# 8

# %%
string2 = "This is python code"
sub2string = "PYthon"
print(string2.index(sub2string))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 3
#       1 string2 = "This is python code"
#       2 sub2string = "PYthon"
# ----> 3 print(string2.index(sub2string))
#
# ValueError: substring not found
