# %%
def abc():   # PARAMETERS
    print("OKK")

# %%
abc()      # ARGUMENTS
# Out:
# OKK

# %%
def xyz():
    g = int(input("Enter num1 : "))
    w = int(input("Enter num2 : "))
    print("Answer :",g+w)

# %%
xyz()
# Out:
# Enter num1 :  8
# Enter num2 :  1
# Answer : 9

# %%
def awe(r,t):
    print("Add:",r+t)

# %%
awe(4,2)
# Out:
# Add: 6

# %%
awe(5,8)
# Out:
# Add: 13

# %%
def welcome_message():     # Declaration of Function
    print("===================================")
    print(" Indian Railways Reservation ")
    print()
    print("===================================")
    print("Welcome to Railway Reservation System")

# %%
welcome_message()    # calling function
# Out:
# ===================================
#  Indian Railways Reservation
#
# ===================================
# Welcome to Railway Reservation System

# %%
def book_ticket(passenger_name, train_name):
   print("Passenger Name :", passenger_name)
   print("Train Name :", train_name)
   print("Reservation Status : Confirmed")

# %%
book_ticket("Rahul Sharma","Rajdhani Express")
# Out:
# Passenger Name : Rahul Sharma
# Train Name : Rajdhani Express
# Reservation Status : Confirmed

# %%
book_ticket(
   "ABC XYZ",
   "PQR DEF")
# Out:
# Passenger Name : ABC XYZ
# Train Name : PQR DEF
# Reservation Status : Confirmed

# %%
book_ticket("ABC XYZ"," ERER E")
# Out:
# Passenger Name : ABC XYZ
# Train Name :  ERER E
# Reservation Status : Confirmed

# %%
passenger_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 passenger_name
#
# NameError: name 'passenger_name' is not defined

# %%
def calculate_fare(ticket_price, passengers):
   total_amount = ticket_price * passengers
   return total_amount

# %%
calculate_fare(56.67 , 89.12)
# Out:
# 5050.4304

# %%
calculate_fare("okk " , 5)
# Out:
# 'okk okk okk okk okk '

# %%
def verify_passenger(age):
   if age >= 18:
       return "Eligible for Reservation"
   else:
       return "Not Eligible"

# %%
verify_passenger(20)
# Out:
# 'Eligible for Reservation'

# %%
verify_passenger(8)
# Out:
# 'Not Eligible'

# %%
def generate_ticket(passenger_name,train_name,seat_number):
   print("===================================")
   print(" Railway Reservation Ticket ")
   print("===================================")
   print("Passenger Name :", passenger_name)
   print("Train Name :", train_name)
   print("Seat Number :", seat_number)

# %%
generate_ticket("Priya Singh","Shatabdi Express","B2-11")
# Out:
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : Priya Singh
# Train Name : Shatabdi Express
# Seat Number : B2-11

# %%
generate_ticket("asdf","janta Express","B2-41")
# Out:
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : asdf
# Train Name : janta Express
# Seat Number : B2-41

# %%
def final_booking_system():

   passenger_name = "Rahul Sharma"
   train_name = "Rajdhani Express"
   seat_number = "A1-12"
   ticket_price = 2450

   print("===================================")
   print(" Indian Railways Reservation ")
   print("===================================")
   print("Passenger Name :", passenger_name)
   print("Train Name :", train_name)
   print("Seat Number :", seat_number)
   print("Ticket Price :", ticket_price)
   print("Reservation Confirmed")

# %%
final_booking_system()
# Out:
# ===================================
#  Indian Railways Reservation
# ===================================
# Passenger Name : Rahul Sharma
# Train Name : Rajdhani Express
# Seat Number : A1-12
# Ticket Price : 2450
# Reservation Confirmed

# %%
def final_booking_system():

   passenger_name = input("Enter ur FULL NAME")
   train_name = "Rajdhani Express"
   seat_number = input("Enter ur Seat Number : ")
   ticket_price = 2450

   print("===================================")
   print(" Indian Railways Reservation ")
   print("===================================")
   print("Passenger Name :", passenger_name)
   print("Train Name :", train_name)
   print("Seat Number :", seat_number)
   print("Ticket Price :", ticket_price)
   print("Reservation Confirmed")

# %%
final_booking_system()
# Out:
# Enter ur FULL NAME khushbu birhade
# Enter ur Seat Number :  34-39
# ===================================
#  Indian Railways Reservation
# ===================================
# Passenger Name : khushbu birhade
# Train Name : Rajdhani Express
# Seat Number : 34-39
# Ticket Price : 2450
# Reservation Confirmed

# %%
def final_booking_system(a = "none"):
    print("A: ",a)
    passenger_name = input("Enter ur FULL NAME")
    train_name = "Rajdhani Express"
    seat_number = input("Enter ur Seat Number : ")
    ticket_price = 2450

    print("===================================")
    print(" Indian Railways Reservation ")
    print("===================================")
    print("Passenger Name :", passenger_name)
    print("Train Name :", train_name)
    print("Seat Number :", seat_number)
    print("Ticket Price :", ticket_price)
    print("Reservation Confirmed")

# %%
final_booking_system(6)
# Out:
# A:  6
# Enter ur FULL NAME rtyy
# Enter ur Seat Number :  8999
# ===================================
#  Indian Railways Reservation
# ===================================
# Passenger Name : rtyy
# Train Name : Rajdhani Express
# Seat Number : 8999
# Ticket Price : 2450
# Reservation Confirmed

# %%
final_booking_system()
# Out:
# Enter ur FULL NAME bn
# Enter ur Seat Number :  67
# ===================================
#  Indian Railways Reservation
# ===================================
# Passenger Name : bn
# Train Name : Rajdhani Express
# Seat Number : 67
# Ticket Price : 2450
# Reservation Confirmed
