# %%
g = 89
print(g)
# Out:
# 89

# %% [markdown]
# # VARIABLE
# ## VARIABLE
# ### VARIABLE
# #### VARIABLE
# ##### VARIABLE

# %%
y_t = 67          # Y_T IS A VARIABLE HERE AND VALUE IS 67 
print(y_t)
print(type(y_t))
# Out:
# 67
# <class 'int'>

# %%
n2m = "okkk"
print(n2m)
# Out:
# okkk

# %%
print3 = 789
print(print3)
# Out:
# 789

# %%
M = 7888
"""
this is (Mutiline Comment)
my python code
for 
batch309
all students are
present"""
print(M)
# Out:
# 7888

# %%
b = """(multiline value)
this is 
my python code
for 
batch309
all students are
present"""
print(b)
b
# Out:
# (multiline value)
# this is
# my python code
# for
# batch309
# all students are
# present
# '(multiline value)\nthis is \nmy python code\nfor \nbatch309\nall students are\npresent'

# %%
print("""
this is (Multiline Comment)
my python code
for 
batch309
all students are
present""")
# Out:
# this is (Multiline Comment)
# my python code
# for
# batch309
# all students are
# present

# %%
"""
this is (Multiline Comment)
my python code
for 
batch309
all students are
present"""
# Out:
# '\nthis is (Multiline Comment)\nmy python code\nfor \nbatch309\nall students are\npresent'

# %%
'''
This is (Multiline Comment)
my python code
for 
batch309
all students are
present
'''
# Out:
# '\nThis is (Multiline Comment)\nmy python code\nfor \nbatch309\nall students are\npresent\n'

# %%
g = 7
print(g)
e = 5
print(e)
g = 2
print(g)
# Out:
# 7
# 5
# 2

# %%
g
# Out:
# 2

# %%
e
# Out:
# 5

# %%
print(e > 4)
# Out:
# True

# %%
print(e < 4)
# Out:
# False

# %%
print(e == 4)
# Out:
# False

# %% [markdown]
# # Operators
#
# ### 1) Arithmetic Operator
# ### 2) Comparision Operator
# ### 3) Logical Operator
# ### 4) Bitwise Operator
# ### 5) Membership Operator
# ### 6) Identity Operator

# %% [markdown]
# ##### 1) Arithmetic Operators

# %%
w = 9
q = 2
print("Addition of W & Q  :",w+q)
print("Substraction of W & Q  :",w-q)
print("Multi of W & Q  :",w*q)
print("Division  of W & Q :",w/q)
# Out:
# Addition of W & Q  : 11
# Substraction of W & Q  : 7
# Multi of W & Q  : 18
# Division  of W & Q : 4.5

# %%
w3 = 9
q3 = "2"
print(w3,q3)
# Out:
# 9 2
