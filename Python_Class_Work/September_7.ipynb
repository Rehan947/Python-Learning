# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup

# %%
rt = "https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&utm_medium=DSDA10_Offline&utm_campaign=Generic_Ahmedabad&utm_term=it%20training%20institute&utm_location=9061748&utm_device=c&utm_adgroupid=195200758979&utm_network=g&gad_source=1&gad_campaignid=22877782544&gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE"
rt
# Out:
# 'https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&utm_medium=DSDA10_Offline&utm_campaign=Generic_Ahmedabad&utm_term=it%20training%20institute&utm_location=9061748&utm_device=c&utm_adgroupid=195200758979&utm_network=g&gad_source=1&gad_campaignid=22877782544&gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE'

# %%
import requests

# %%
we2 = requests.get(rt)
we2
# Out:
# <Response [200]>

# %%
df = "https://mimo.org/glossary/python/filter"

# %%
we3 = requests.get(df)
we3
# Out:
# <Response [200]>

# %%
bn = "https://www.imdb.com/"
dr = requests.get(bn)
dr
# Out:
# <Response [403]>

# %%
rt
itt = BeautifulSoup(rt , "html.parser")
itt.text
# Out:
# 'https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&utm_medium=DSDA10_Offline&utm_campaign=Generic_Ahmedabad&utm_term=it%20training%20institute&utm_location=9061748&utm_device=c&utm_adgroupid=195200758979&utm_network=g&gad_source=1&gad_campaignid=22877782544&gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE'

# %%
rt
itt = BeautifulSoup(we2.text , "html.parser")
itt
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- title -->
# <!-- google bot -->
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=0" /> -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <!-- page specific meta tags
#    -->
# <!-- favicon -->
# <link href="https://www.itvedant.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- meta info -->
# <title>Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad</title>
# <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" name="description">
# <meta content="data science course in ahmedabad, data analytics course in ahmedabad" name="keywords"/>
# <link href="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" rel="canonical"/>
# <!-- open graph tags -->
# <meta content="Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad" property="og:title"/>
# <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" property="og:url"/>
# <meta content="https://www.itvedant.com/images/footer-logo.png" property="og:image"/>
# <!-- Twitter Meta Tags -->
# <meta content="summary" name="twitter:card"/>
# <meta content="www.itvedant.com" property="twitter:domain"/>
# <meta content="@itvedant" name="twitter:site">
# <meta content="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" property="twitter:url"/>
# <meta content="Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad" name="twitter:title"/>
# <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" name="twitter:description"/>
# <meta content="https://www.itvedant.com/images/footer-logo.png" name="twitter:image"/>
# <link href="https://connect.facebook.net" rel="preconnect"/>
# <link href="https://connect.facebook.net" rel="dns-prefetch"/>
# <script>
#   function loadScript(url) {
#     const script = document.createElement('script');
#     script.src = url;
#     document.head.append(script);
#     return script;
#   }
#
#   function loadScriptDelay(url) {
#     // Use setTimeout with 0 delay to run the script loading after the main thread is free
#     setTimeout(function() {
#       const script = document.createElement('script');
#       script.src = url;
#       document.head.append(script);
#       return script;
#     }, 5000);
#   }
#
#   function loadScriptAsync(url) {
#     return new Promise((resolve, reject) => {
#       const script = document.createElement('script');
#
#       script.src = url;
#
#       script.onload = () => resolve();
#       script.onerror = (error) => reject(error);
#
#       document.body.append(script);
#     });
#   }
#
#   document.addEventListener('DOMContentLoaded', async function() {
#     await loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js');
#         loadScript('https://www.itvedant.com/js/coursewise-video-min.js?v=1782927482');
#
#     await loadScriptAsync('https://www.itvedant.com/slick/slick.min.js?v=1782927482');
#     await loadScriptAsync('https://www.itvedant.com/dest/js/main-min.js?v=1782927482');
#
#
#     loadScript('https://www.itvedant.com/dest/js/form-min.js?v=1787845438');
#     // loadScript('<?//= $path ?>/js/popup-config-min.js');
#
#     // loadScript('<?//= $path ?>/js/right-menu.js');
#     loadScript('https://www.itvedant.com/bootstrap/js/bootstrap.min.js');
#     loadScript('https://www.itvedant.com/bootstrap/js/lazysizes.min.js');
#
#     //load google location js
#     loadScript('https://www.itvedant.com/js/google-location.js?v=1788453813');
#
#     // $('.rotating-menu-arrow').click(function() {
#     //   $(this).find(".menu-rotate").toggleClass('rotating-arrow-animation');
#     // });
#
#     $('.menu-item').click(function(){
#       if(!($(this).hasClass('active'))){
#
#         $(this).find(".menu-rotate").addClass('rotating-arrow-animation');
#       }
#       else{
#         $(this).find(".menu-rotate").removeClass('rotating-arrow-animation');
#       }
#
#     });
#
#
#         // loadScriptDelay('https://www.itvedant.com/js/batch-countdown.js');
#         //   loadScript('https://www.itvedant.com/js/batch-countdown.js');
#     //
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         loadScript('https://www.itvedant.com/js/students-reviews-min.js?v=1782927482');
#     loadScript('https://www.itvedant.com/dest/js/trust-component-min.js?v=1782927482');
#
#
#           loadScript('https://www.itvedant.com/dest/js/industry-project-min.js?v=1782927482');
#
#
#
#
#
#
#
#
#
#
#
#
#           });
# </script>
# <!-- <script src="<? //= $path
#                     ?>/bootstrap/cached-webpgr.min.js"></script> -->
# <script>
#             switch(window.location.host)
#             {
#               case "localhost"        : path = "http://localhost/itvedant-website-2024"; break;
#               case "itvedant.test"    : path = "http://itvedant.test"; break;
#               case "www.itvedant.test": path = "http://www.itvedant.test"; break;
#               case "aws.itvedant.com" : path = "https://aws.itvedant.com"; break;
#               default                 : path = "https://www.itvedant.com";
#             }
#
#             var site_url                = "https://www.itvedant.com";
#             var api_url                 = "https://api.itvedant.com/index.php";
#             var sms_url                 = "https://www.itvedant.com/itv_forms";
#             var site_key                = "6LdsStQqAAAAAEV4rVCPjh76nujlzPMNxZTVTTUc";
#             var ip_address                = "20.0.1.49";
#             var user_agent                = "python-requests/2.32.3";
#             var form_name_list          = {"1":"course_selector_submit","2":"get_career_guidance_submit","3":"banner_download_brochure_submit","4":"section_download_brochure_submit","5":"banner_form_submit","6":"stats_inquire_now_submit","7":"inquire_footer_submit","8":"inquire_now_footer_submit","9":"course_download_brochure_submit","10":"certificate_inquire_now_submit","11":"career_report_submit","12":"placement_freecounseling_submit","13":"placement_date_request_submit","14":"hiring_partners_inquire_now_submit","15":"pay_fees_submit","16":"refer_n_earn_submit","17":"success_stories_inquire_now_submit","18":"success_stories_brochure_download_submit","19":"growth_inqiury_submit","20":"contact_us_submit","21":"recurring_popup_submit","22":"digi_marketing_banner_form_submit","23":"popup_form_placement_report_first_submit","24":"popup_form_placement_report_second_submit","25":"popup_form_placement_report_third_submit","26":"popup_form_resume_handbook_submit","27":"popup_form_discount_offer","28":"popup_form_emi","29":"popup_form_nearest_branch","30":"executive_program_form","31":"master_class_form","32":"book_my_seat_form","33":"dsda_nigeria_form","34":"no_email_personal_information_form","35":"no_email_download_brochure_form"};
#             var compaign_branch_list    = {"thane":"1","andheri":"2","eclass":"3","navimumbai":5,"pune":6,"bengaluru":"7","chennai":"8","hyderabad":"9","borivali":"11","delhi":"12","pimple":"13","pimpri":"13","pimprichinchwad":"13","pimpri-chinchwad":"13","katraj":"14","kalyan":"15","dadar":"16","nagpur":"17","ahmedabad":"18","lucknow":"20","nashik":"21","e-class":"3","headoffice":"4","head-office":"4","vashi":"5","fcroad":"6","fc-road":"6","bangalore":"7","noida":"22","africa":"23","vasai":"25"};
#             var course_packages         = {"\/aws-azure-cloud-technology":"Master In AWS Cloud Technology","\/data-science-and-ai":"Master in Data Science & Analytics with Artificial Intelligence","\/python-full-stack-developer-course":"Master in Full Stack Web Development with Python","\/java-full-stack-developer-course":"Master in Full Stack Web Development with Java","\/data-software-engineering":"Masters in Data Software Engineering","\/digital-marketing-course":"Master in Digital Marketing with AI","\/contact":"","\/itvedant-website":"","\/refer-and-earn":"","\/enrol":"","www.itvedant.com":""};
#             var brochure_list           = {"default":{"modal_title":"Download Brochure","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software":{"modal_title":"Download Brochure","image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"aws-technology":{"modal_title":"Download Brochure","image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"digital-marketing":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"data-science":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"placement-report":{"modal_title":"Download Placement Report","image":"career-books.webp","brochure_name":"career_report","alt":"career_report"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"python-course":{"image":"home_page.webp","brochure_name":"python_modular","alt":"itvedant brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant brochure"},"data-analytics-course":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"modal_title":"Download Brochure","image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"modal_title":"Download Brochure","image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"modal_title":"Download Brochure","image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"success-stories":{"modal_title":"Download Success Stories","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"full-stack-course":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"ml-course":{"modal_title":"Download Brochure","image":"data-science-and-ai.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant machine learning brochure"},"social-media-marketing-course":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"sql-course":{"modal_title":"Download Brochure","image":"ful ...
#             var bouchure_image_list     =  {"index":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software-engineering":{"image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"digital-marketing":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-data-science-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"online-software-testing-course":{"image":"software-testing.webp","brochure_name":"st","alt":"software testing brochure"},"online-devops-with-aws-course":{"image":"","brochure_name":"","alt":""},"devops-with-aws-course":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"aws-azure-cloud-technology":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"data-science-and-ai":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"success-stories":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"placements":{"image":"career-books.webp","brochure_name":"career_report","alt":"itvedant brochure"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"data-science-masterclass-for-executives":{"image":"home_page.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"python-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"data-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"cor ...
#             var custom_new_bouchure_image_list     =  {"default":{"modal_title":"Download Brochure","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"masters_in_data_science_with_ai_and_aws.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"master_certification_in_full_stack_development.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant brochure"},"master_in_java.pdf":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development.pdf":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"master_in_aws_azure_cloud_technology.pdf":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"digital_marketing.pdf":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"executive.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"career_report.pdf":{"image":"career-books.webp","brochure_name":"career_report","alt":"career report"},"executive_program_devops_with_aws.pdf":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"investment_banking_with_ai.pdf":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking with ai brochure"},"master_in_software_testing_with_ai.pdf":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing with ai brochure"},"masters_in_data_science_with_ai_nigeria.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"masters_in_data_science_with_ai_nigeria","alt":"itvedant data science and ai brochure"}};
#             var current_branch_id       = "18";
#             var form_current_branch_id  = "18";
#             var page                    = "";
#             var course                  = "data-science-and-ai";
#             var is_ipinfo               = 0;
#             var branch_info             = {"thane":{"id":1,"name":"Thane","icon":"thane.svg","icon_alt":"Itvedant Thane Branch","address":"2nd Floor, Ishaan Arcade-1, Opposite Gaondevi Mandir, Above Canara bank, Gokhale Road,Landmark: 3 Buildings after McDonalds, Thane (West)","pincode":"400602","geolocation":{"lat":"19.187644486358995","lng":"72.9738175"},"time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"wa_contact":9205004404,"thumbnail_imgs":["thane1.webp","thane2.webp","thane3.webp","thane4.webp"],"thumbnail_imgs_alt":["Itvedant Thane reception - 2","Itvedant Thane reception - 1","Itvedant Thane reception - 3","Itvedant Thane Cafeteria"],"imgs":["thane1.webp","thane2.webp","thane3.webp","thane4.webp","thane5.webp","thane6.webp"],"imgs_text":["Sit Out Area At Thane Branch"," Campus Placement drive at Thane branch","Classroom training at Thane branch","Campus Placement drive at Thane branch"," Career Counselling session at Thane branch","Classroom training at Thane branch"],"imgs_alt":["Sit Out Area At Thane Branch"," Campus Placement drive at Thane branch","Classroom training at Thane branch","Campus Placement drive at Thane branch"," Career Counselling session at Thane branch","Classroom training at Thane branch"],"direction":"https:\/\/g.page\/Itvedant?share","country":"IN"},"andheri":{"id":2,"name":"Andheri","icon":"andheri.svg","icon_alt":"Itvedant Andheri Branch","address":"1st Floor Bina Apartments,Beside Ganpati Mandir,Opposite Arasa Hotel, Near Andheri Metro Station, Andheri (East), Mumbai","pincode":"400069","time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"geolocation":{"lat":"19.120030187551304","lng":"72.85017889999999"},"wa_contact":9205004404,"thumbnail_imgs":["andheri1.webp","andheri2.webp","andheri3.webp","andheri4.webp"],"thumbnail_imgs_alt":["Itvedant Andheri reception - 1","Itvedant Andheri elevator","Itvedant Andheri waiting area-1","Itvedant Andheri waiting area-2"],"imgs":["andheri1.webp","andheri2.webp","andheri3.webp","andheri4.webp","andheri5.webp","andheri6.webp"],"imgs_text":["Reception area at Andheri branch","Itvedant Andheri Elevator","Sit Out area at Andheri branch"," Classroom training at Andheri branch","Classroom training at Andheri branch","Learners Facilitation At Andheri Branch"],"imgs_alt":["Reception area at Andheri branch","Itvedant Andheri Elevator","Sit Out area at Andheri branch"," Classroom training at Andheri branch","Classroom training at Andheri branch","Learners Facilitation At Andheri Branch"],"direction":"https:\/\/g.page\/Itvedant-andheri?share","country":"IN"},"borivali":{"id":11,"name":"Borivali","icon":"borivali.svg","icon_alt":"Itvedant Borivali Branch","address":"1st Floor, Bhandarkar Bhavan, S.V. Road Court Lanes, Near Police Station, Opp. Borivali Railway Station, Borivali West, Mumbai, Maharashtra","pincode":"400092","time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"geolocation":{"lat":"19.23006337498649","lng":"72.85586843752289"},"wa_contact":9205004404,"thumbnail_imgs":["borivali1.webp","borivali2.webp","borivali3.webp","borivali4.webp"],"thumbnail_imgs_alt":["Itvedant Borivali Reception-1","Itvedant Borivali Classroom - 1","Itvedant Borivali Counselling Cabin-1","Itvedant Borivali Reception-2","Itvedant Borivali Counselling Cabin-2","Itvedant Borivali Washroom"],"imgs":["borivali1.webp","borivali2.webp","borivali3.webp","borivali4.webp","borivali5.webp","borivali6.webp"],"imgs_text":["Classroom training at Borivali branch","Happy Learners of Borivali branch","Classroom training at Borivali branch","  Sit Out Area At Borivali Branch","Career Counselling session at Borivali branch"," Career Counselling session at Borivali branch"],"imgs_alt":["Classroom training at Borivali branch","Happy Learners of Borivali branch","Classroom training at Bor ...
#             var enrol_branch_list       = {"1":"thane","2":"andheri","3":"eclass","5":"navi-mumbai","6":"pune","7":"bengaluru","8":"chennai","9":"hyderabad","11":"borivali","12":"delhi","13":"pimpri-chinchwad","14":"katraj","15":"kalyan","16":"dadar","17":"nagpur","18":"ahmedabad","20":"lucknow","21":"nashik","4":"head-office","22":"noida","23":"africa","25":"vasai"};
#             var branch_name_list    = {"1":"Thane","2":"Andheri","3":"E-Class","4":"Head Office","5":"Vashi","6":"FC Road","7":"Bengaluru","8":"Chennai","9":"Hyderabad","11":"Borivali","12":"Delhi","13":"Pimpri","14":"Katraj","15":"Kalyan","16":"Dadar","17":"Nagpur","18":"Ahmedabad","20":"Lucknow","21":"Nashik","22":"Noida","23":"Africa","25":"Vasai"};
#             window.js_branch_data   = {"js_locations":[{"name":"1","lat":"19.187644486358995","lng":"72.9738175","state":"Central"},{"name":"2","lat":"19.120030187551304","lng":"72.85017889999999","state":"Western"},{"name":"5","lat":"19.06652154674476","lng":"72.9990716711645","state":"Central"},{"name":"7","lat":"12.916461604745717","lng":"77.61119818650646","state":"South"},{"name":"8","lat":"13.084797955268899","lng":"80.21185888465804","state":"South"},{"name":"9","lat":"17.498283088472903","lng":"78.39012807116451","state":"South"},{"name":"11","lat":"19.23006337498649","lng":"72.85586843752289","state":"Western"},{"name":"12","lat":"28.571474564873693","lng":"77.21968096192246","state":"North"},{"name":"14","lat":"18.450154920279193","lng":"73.85778906931611","state":"Pune"},{"name":"15","lat":"19.236793549985745","lng":"73.1292745","state":"Central"},{"name":"16","lat":"19.01675523226402","lng":"72.8439855","state":"Western"},{"name":"17","lat":"21.13951025748816","lng":"79.06024855767097","state":"Pune"},{"name":"18","lat":"23.035768667229622","lng":"72.56106715120089","state":"Western"},{"name":"20","lat":"26.850301903455694","lng":"80.94334206734158","state":"North"},{"name":"21","lat":"20.00667278356107","lng":"73.75947534232903","state":"Central"},{"name":"22","lat":"28.62801504462737","lng":"77.37608371349255","state":"North"},{"name":"23","lat":"6.621723592983252","lng":"3.3526240992236267","state":"Overseas"},{"name":"25","lat":"19.383602493539886","lng":"72.83118418654539","state":"Western"}],"js_names":{"1":"Thane","2":"Andheri","3":"E-Class","4":"Head Office","5":"Vashi","6":"FC Road","7":"Bengaluru","8":"Chennai","9":"Hyderabad","11":"Borivali","12":"Delhi","13":"Pimpri","14":"Katraj","15":"Kalyan","16":"Dadar","17":"Nagpur","18":"Ahmedabad","20":"Lucknow","21":"Nashik","22":"Noida","23":"Africa","25":"Vasai"},"campaign_map":{"thane":"thane","andheri":"andheri","e-class":"e-class","headoffice":"head-office","head-office":"head-office","vashi":"vashi","fcroad":"fc-road","fc-road":"fc-road","bengaluru":"bengaluru","bangalore":"bengaluru","chennai":"chennai","hyderabad":"hyderabad","borivali":"borivali","delhi":"delhi","pimpri":"pimpri","pimple":"pimpri","katraj":"katraj","kalyan":"kalyan","dadar":"dadar","nagpur":"nagpur","ahmedabad":"ahmedabad","lucknow":"lucknow","nashik":"nashik","noida":"noida","africa":"africa","vasai":"vasai"}};
#             var google_api_key          = "AIzaSyC9G-faB5BCN6DsJxpgy-ZinWJG0R_nhLE";
#             var cookie_expiry_minutes   = 43200;
#             var TRACKING_CONFIG = {
#                 GA4: "G-VYPTR9R8L7",
#                 AW_LEAD: "AW-826880244/52oZCPibipYBEPThpIoD",
#                 AW_MOBILE: "AW-826880244/X1SICIGzofAaEPThpIoD",
#                 AW_CONTACT: "AW-826880244/4SG7CNXTyIccEPThpIoD"
#             };
#             window.INTL_MOBILE_RULE = null;
#       </script><script>var current_branch_id = 18;  var form_current_branch_id = 18;</script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       dataLayer.push({
#         'gtm.blocklist': ['.view-batch-details-click']
#       });
#     </script>
# <!-- CSS files -->
# <link as="style" href="https://www.itvedant.com/bootstrap/css/bootstrap.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="https://www.itvedant.com/bootstrap/css/bootstrap-icons.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="https://www.itvedant.com/slick/slick.min.css?v=1782927482" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="https://www.itvedant.com/slick/slick-theme.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link href="https://www.itvedant.com/dest/css/main.min.css?v=1787678638" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/our-upcoming-section.css?v=1788528877" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/course-curriculum.css?v=1782927482" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/wingz-section.css?v=1782927482" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/trainer-list.css?v=1787678638" rel="stylesheet"/>
# <link as="style" href="https://www.itvedant.com/css/personal-coach.css?v=1782927482" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript>
# <link href="https://www.itvedant.com/css/personal-coach.css?v=1782927482" rel="stylesheet"/>
# </noscript>
# <link as="style" href="https://www.itvedant.com/css/batch-countdown.css" onload="this.onload=null;this.rel='stylesheet'" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/campus-placement-drive.css?v=1782927482" rel="stylesheet"/>
# <!-- all popup css -->
# <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/css/popup/popup-forms.css?v=1782927482"> -->
# <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/templates/popups/default/css/popup-form-emi.css"> -->
# <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/templates/popups/default/css/popup-form-branches.css"> -->
# <script>
#     ! function(e) {
#       "function" == typeof define && define.amd ? define(e) : e()
#     }(function() {
#       var e, t = ["scroll", "wheel", "touchstart", "touchmove", "touchenter", "touchend", "touchleave", "mouseout", "mouseleave", "mouseup", "mousedown", "mousemove", "mouseenter", "mousewheel", "mouseover"];
#       if (function() {
#           var e = !1;
#           try {
#             var t = Object.defineProperty({}, "passive", {
#               get: function() {
#                 e = !0
#               }
#             });
#             window.addEventListener("test", null, t), window.removeEventListener("test", null, t)
#           } catch (e) {}
#           return e
#         }()) {
#         var n = EventTarget.prototype.addEventListener;
#         e = n, EventTarget.prototype.addEventListener = function(n, o, r) {
#           var i, s = "object" == typeof r && null !== r,
#             u = s ? r.capture : r;
#           (r = s ? function(e) {
#             var t = Object.getOwnPropertyDescriptor(e, "passive");
#             return t && !0 !== t.writable && void 0 === t.set ? Object.assign({}, e) : e
#           }(r) : {}).passive = void 0 !== (i = r.passive) ? i : -1 !== t.indexOf(n) && !0, r.capture = void 0 !== u && u, e.call(this, n, o, r)
#         }, EventTarget.prototype.addEventListener._original = e
#       }
#     });
#
#     /* document.addEventListener('DOMContentLoaded', async function() {
#       const head  = document.getElementsByTagName('head')[0];
#       const link  = document.createElement('link');
#       link.rel  = 'stylesheet';
#       link.type = 'text/css';
#       link.href = 'https://www.itvedant.com/bootstrap/css/bootstrap-icons.min.css';
#       link.media = 'all';
#       head.appendChild(link);
#     }); */
#   </script>
# <!-- Conversion Tracking -->
# <!-- Preconnect -->
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://connect.facebook.net" rel="preconnect"/>
# <!-- Google Tag -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-YVPTR9RBL7"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config','G-YVPTR9RBL7');
# gtag('config','AW-826880244');
# </script>
# <!-- Meta Pixel -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init',"27800555899562405");
# fbq('track','PageView');
# </script>
# <link href="https://www.itvedant.com/css/placement.css?v=1782927482" rel="stylesheet"/>
# <link href="https://www.itvedant.com/css/new-wingz-component.css?v=1782927482" rel="stylesheet"/>
# </meta></meta></meta></head>
# <body>
# <!-- call fix for Web -->
# <div class="webfix d-none d-md-block">
# </div>
# <div class="webfix d-none d-md-block">
# </div>
# <div class="main">
# <nav class="p-4">
# <div class="container">
# <div class="row mobile-logo-align">
# <div class="col-xl-7 col-lg-7 col-md-6 col-sm-6 col-6 d-flex align-items-center p-0">
# <a href="https://www.itvedant.com">
# <img alt="Itvedant" fetchpriority="high" height="100%" src="https://www.itvedant.com/images/itv-logo.svg" width="auto"/>
# </a>
# <div class="dropdown-left" id="course-menu">
# <ul>
# <li>
# <a class="exp text-decoration-none" href="#">Explore Courses<img alt="Explore Courses icon" loading="lazy" src="https://www.itvedant.com/images/rotation.svg"/></a>
# <div class="itv-menu-container main-menu-divs position-absolute" style="display: none;">
# <div class="itv-menu-sidebar d-none">
# <div>
# <div class="itv-menu-tab itv-menu-active" data-target="itv-menu-freshers">For Freshers</div>
# <div class="itv-menu-tab d-flex justify-content-between" data-target="professionals">For Working Professionals</div>
# </div>
# <div>
# <p class="talk-expert-menu">
# <span>Looking for Guidance ?</span>
# <a class="talk-button talk-with-guide text-dark" href="tel:9205004404" target="_blank">Talk To Career Guide <i class="bi bi-telephone text-dark pl-2"></i></a> </p>
# </div>
# </div>
# <div class="itv-menu-content">
# <div class="itv-menu-course-group" id="itv-menu-freshers" style="display: block;">
# <a class="text-decoration-none" href="https://www.itvedant.com/data-science-and-ai">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Data Science &amp; Analytics with AI</p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/full-stack-developer-course">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Full Stack Development</p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/devops-with-aws-course">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">DevOps with AWS</p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/digital-marketing-course">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Digital Marketing with AI</p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/investment-banking-course">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Investment Banking with AI </p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/software-testing-course">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Software Testing With AI </p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <a class="text-decoration-none" href="https://www.itvedant.com/cyber-security-ethical-hacking-with-ai-course ">
# <div class="course-card row">
# <div class="col-md-10">
# <div class="course-row">
# <div>
# <p class="course-title">Cyber Security &amp; Ethical Hacking with AI </p>
# <p class="course-duration">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                                     Duration : 6 Months
#                                   </p>
# </div>
# </div>
# </div>
# <div class="col-md-2 d-flex align-items-center">
# <span class="course-arrow">
# <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
# </span>
# </div>
# </div>
# </a>
# <div>
# <p class="talk-expert-menu">
# <span>Looking for Guidance ?</span>
# <a class="talk-button talk-with-guide text-dark" href="tel:9205004404" target="_blank">Talk To Career Guide <i class="bi bi-telephone text-dark pl-2"></i></a> </p>
# </div>
# </div>
# <div class="itv-menu-course-group" id="professionals">
# <div class="row">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="crm d-none" data-target="#course-selector" data-toggle="modal" id="course_selector_form_click">Course Selector <img alt="" loading="lazy" src="https://www.itvedant.com/images/path.svg"/></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-5 col-lg-5 col-md-6 col-sm-6 col-6 d-flex justify-content-end">
# <div class="right_menu">
# <ul>
# <li><button class="c-guide trigger-custom-modal" data-custom-popup-in-popup-flow="true" data-modal-link="https://www.itvedant.com/templates/popups/default/forms/popup-career-guidance.php" data-target="#custom-career-guidance-modal" data-toggle="modal" itv-btn-type="get_career_guidance_submit"> Get Career Guidance <img alt="arrow" loading="lazy" src="https://www.itvedant.com/images/career-guide-icon.svg"/></button></li>
# </ul>
# </div>
# <div class="navbars">
# <button class="c-guide mr-4 cg-mobile trigger-custom-modal" data-custom-popup-in-popup-flow="true" data-modal-link="https://www.itvedant.com/templates/popups/default/forms/popup-career-guidance.php" data-target="#custom-career-guidance-modal" data-toggle="modal" itv-btn-type="get_career_guidance_submit">
# <img alt="arrow" fetchpriority="high" src="https://www.itvedant.com/images/career-guide-icon.svg"/></button>
# <span class="open-menu" fetchpriority="high">
# <svg height="16" width="24" xmlns="http://www.w3.org/2000/svg">
# <g fill="#252a32" fill-rule="evenodd">
# <path d="M0 0h24v2H0zM0 7h24v2H0zM0 14h24v2H0z"></path>
# </g>
# </svg>
# </span>
# <div class="menu-wrapper">
# <ul class="menu">
# <li class="menu-block">
# <span class="close-menu">
# <svg height="20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M17.778.808l1.414 1.414L11.414 10l7.778 7.778-1.414 1.414L10 11.414l-7.778 7.778-1.414-1.414L8.586 10 .808 2.222 2.222.808 10 8.586 17.778.808z" fill="#252a32" fill-rule="evenodd"></path>
# </svg>
# <strong class="closing-align"></strong>
# </span>
# </li>
# <li class="menu-item has-collapsible active" id="query2">
# <a class="p-0 cursor-pointer">
# <span class="rotating-menu-arrow" style="padding: 0 1rem;">
#                         All Courses
#                         <svg class="bi bi-chevron-right" fill="currentColor" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M4.646 1.646a.5.5 0 0 1 .708 0l6 6a.5.5 0 0 1 0 .708l-6 6a.5.5 0 0 1-.708-.708L10.293 8 4.646 2.354a.5.5 0 0 1 0-.708z" fill-rule="evenodd"></path>
# </svg>
# </span>
# </a>
# <ul class="menu-child" id="course2">
# <li class="menu-child-item"><a href="https://www.itvedant.com/data-science-and-ai"> Data Science &amp; Analytics with AI </a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/full-stack-developer-course">Full Stack Development </a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/devops-with-aws-course">DevOps with AWS </a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/digital-marketing-course">Digital Marketing with AI </a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/investment-banking-course">Investment Banking with AI </a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/software-testing-course">Software Testing With AI</a></li>
# <li class="menu-child-item"><a href="https://www.itvedant.com/cyber-security-ethical-hacking-with-ai-course ">Cyber Security &amp; Ethical Hacking with AI</a></li>
# </ul>
# </li>
# <li class="menu-item has-collapsible cursor-pointer d-none">
# <a class="common-side-txt rotating-menu-arrow" id="query3">
#                       For Working Professionals
#                       <svg class="bi bi-chevron-right" fill="currentColor" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M4.646 1.646a.5.5 0 0 1 .708 0l6 6a.5.5 0 0 1 0 .708l-6 6a.5.5 0 0 1-.708-.708L10.293 8 4.646 2.354a.5.5 0 0 1 0-.708z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <ul class="menu-child">
# <li class="menu-child-item"><a href="https://www.itvedant.com/devops-with-aws-course">DevOps with AWS </a></li>
# </ul>
# </li>
# <li class="menu-item"><a class="menu-link" href="https://www.itvedant.com/placements">Placements</a></li>
# <li class="menu-item"><a class="menu-link" href="https://www.itvedant.com/hire-from-us">Hire From Us</a></li>
# <li class="menu-item"><a class="menu-link" href="https://www.itvedant.com/careers">Careers</a></li>
# <li class="menu-item"><a href="https://www.itvedant.com/refer-and-earn">Refer &amp; Earn</a></li>
# <li class="menu-item"><a href="https://www.itvedant.com/news-and-events">News &amp; Events</a></li>
# <li class="menu-item"><a href="https://www.itvedant.com/success-stories">Success Stories</a></li>
# <li class="menu-item"><a href="https://www.itvedant.com/corporate-training">Corporate Training</a></li>
# <li class="menu-item"><a class="menu-link" href="https://www.itvedant.com/blog/">Blogs</a></li>
# <li class="menu-item"><a class="menu-link" href="https://www.itvedant.com/contact">Contact Us</a></li>
# <li class="talk-expert-menu mobile-hide-menu mt-4 p-0">
# <span>Confused about which course to select?</span>
# <a class="talk-button talk-with-guide" href="tel:9205004404" target="_blank">Talk to Career Expert</a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <button class="sideway g-review-mob-web" data-target="#get_quote_modal" data-toggle="modal" id="modal_view_left">
# <ul>
# <li><img alt="" class="mob-review-lg lazyload" data-src="https://www.itvedant.com/images/google-review.svg" loading="lazy"/></li>
# <li><img alt="" class="mob-review-sm lazyload" data-src="https://www.itvedant.com/images/google-reviews/g-icon-star.svg" loading="lazy"/></li>
# <li><span>Reviews!</span></li>
# <li><img alt="" class="arrow-hover lazyload" data-src="https://www.itvedant.com/images/google-reviews/arrow-right-sidebar.svg" loading="lazy"/></li>
# </ul>
# </button>
# <!-- desktop modal -->
# <div aria-labelledby="myModalLabel2" class="modal main-google-review modal_outer left_modal z-index-popup fade" id="get_quote_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="container">
# <div class="row d-flex align-items-center justify-content-center">
# <div class="col-xl-6 col-lg-6 col-md-6 col-sm-6 col-6">
# <div class="itv-google-img">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/google-reviews.svg" loading="lazy"/>
# </div>
# </div>
# <div class="col-xl-6 col-lg-6 col-md-6 col-sm-6 col-6">
# <button class="close google-review-close-btn" data-dismiss="modal" id="slide-close" type="button">
# <img alt="" class="lazyload" data-src="https://www.itvedant.com/images/cross.svg" loading="lazy"/>
# </button>
# </div>
# </div>
# <div class="row itv-review-info">
# <div class="col-xl-8 col-lg-8 col-md-8 col-sm-8 col-8 g-review-mobile-space">
# <div class="itv-review-count">
# <div class="review-count-list">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/gold-star.svg" loading="lazy"/>
# <p>5</p>
# </div>
# <div class="review-text">
# <div class="review-bar-green">
# <div class="review-five"></div>
# </div>
# </div>
# <span class="review-counts">5266</span>
# </div>
# <div class="itv-review-count">
# <div class="review-count-list">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/gold-star.svg" loading="lazy"/>
# <p>4</p>
# </div>
# <div class="review-text">
# <div class="review-bar-blue">
# <div class="review-four"></div>
# </div>
# </div>
# <span class="review-counts">988</span>
# </div>
# <div class="itv-review-count">
# <div class="review-count-list">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/gold-star.svg" loading="lazy"/>
# <p>3</p>
# </div>
# <div class="review-text">
# <div class="review-bar-pink">
# <div class="review-three"></div>
# </div>
# </div>
# <span class="review-counts">198</span>
# </div>
# <div class="itv-review-count">
# <div class="review-count-list">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/gold-star.svg" loading="lazy"/>
# <p>2</p>
# </div>
# <div class="review-text">
# <div class="review-bar-yellow">
# <div class="review-two"></div>
# </div>
# </div>
# <span class="review-counts">34</span>
# </div>
# <div class="itv-review-count">
# <div class="review-count-list">
# <img alt="" class="img-fluid lazyload" data-src="https://www.itvedant.com/images/g-review/gold-star.svg" loading="lazy"/>
# <p>1</p>
# </div>
# <div class="review-text">
# <div class="review-bar-orange">
# <div class="review-one"></div>
# </div>
# </div>
# ...
# </div>
# </div>
# </div>
# <!-- BEGIN: INQUIRY ID ERROR -->
# <div class="scheduler-list-inquiry">
# <div class="error schedule_form_inquiry_error" style="display:none">
# <span style="font-size:1.5rem;color:red">Something went wrong!</span>
# </div>
# </div>
# <!-- END: INQUIRY ID ERROR -->
# <!-- hidden inputs -->
# <input id="schedule_form_inquiry_id" type="hidden"/>
# <input id="schedule_form_inquiry_name" type="hidden"/>
# <div class="main-card-padd mt-4">
# <button class="schedule-btn bg-black-color w-100 trigger-form-submission" id="schedule2-btnn" type="button">Schedule</button>
# <!-- onclick="submitFormsByType({ event: event, formTypeName: 'FORM_TYPE_SCHEDULE_VISIT', formIdName: 'schedule_form', formModalIdName: 'popup-form-placement-report-first-modal' })" -->
# </div>
# </form>
# </div>
# </div>
# <div class="modal-content schedule-card" id="schedule-3">
# <div class="modal-header align-items-center justify-content-start">
# <img alt="" class="icon-align-schedule lazyload" data-src="https://www.itvedant.com/images/contact/schedule/right-arrow.svg" loading="lazy"/>
# <h2 class="modal-title schedule-heading schedule-visit-validd" id="schedule-visit-heading">Visit Successfully Scheduled </h2>
# <button aria-label="Close" class="close schedule-close" data-dismiss="modal" type="button">
# <img alt="" src="https://www.itvedant.com/images/cross.svg"/>
# </button>
# </div>
# <div class="modal-body bg-lightblue watch-heading">
# <h3>Get ready to meet our Expert at the Branch for Personalised Career Guidance!</h3>
# <div class="student-brochure-button">
# <a class="ml-0 brochure-download-modal popup-brochure-form-btn-type" href="tel:9205004404">
# <img alt="Talk to Career Guide" class="ls-is-cached lazyloaded" height="100%" loading="lazy" src="https://www.itvedant.com/images/mob-call.svg" style="padding-right: 0.5rem; height: 18px;" width="auto">
#                           Talk to Career Guide
#                         </img></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- schedule end here -->
# <div aria-hidden="true" aria-labelledby="exampleModalCenterTitle" class="modal z-index-popup fade" id="placementModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered modal-lg" role="document">
# <div class="modal-content schedule-card" id="placement-3">
# <div class="modal-header align-items-center justify-content-center">
# <strong style=" font-size:large;">Thank you for your interest in candidates for employment</strong>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">
# <img alt="" loading="lazy" src="https://www.itvedant.com/images/cross.svg"/>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <h2 class="modal-title text-center">
# <img alt="" class="icon-align-schedule lazyload d-block m-auto" data-src="https://www.itvedant.com/images/contact/schedule/right-arrow.svg" loading="lazy" width="50"/>
# <p style=" font-size:small;">A team member will contact you shortly to discuss your needs and assist in finding the right candidates from our pool.</p>
# </h2>
# </div>
# </div>
# </div>
# </div><!-- schedule end here -->
# <!-- LOAD MODALS -->
# <div id="load-modal"></div>
# <div id="gtm-tiggers" style="position: fixed;
#     /* background: red; */
#     top: 0;
#     left: 0;
#     z-index: 1000000;">
# <!-- MOBILE NO. GTM TRIGGER -->
# <div class="mobile-number-valid d-none">    </div>
# <div class="schedule-visit-valid d-none">    </div>
# <div class="download-brochure-valid d-none">    </div>
# <div class="book-my-seat-valid d-none">    </div>
# <div class="success-monthly d-none">    </div>
# <div class="success-onetime d-none">    </div>
# </div>
# <!-- LOAD MODALS -->
# <!-- captcha pages -->
# <!-- schema file data -->
# <script type="application/ld+json">{
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "name": "Data Science & Analytics with AI Course in Ahmedabad",
#     "image": "https://www.itvedant.com/images/logo.svg",
#     "description": "Professional data science training institute in Ahmedabad. Data Science & Analytics with AI course & training in Ahmedabad. Certified & placed. Don't Miss Out!",
#     "brand": {
#         "@type": "Brand",
#         "name": "Itvedant EDUCATION PVT. LTD."
#     },
#     "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "4.7",
#         "bestRating": "5",
#         "worstRating": "1",
#         "ratingCount": "1291"
#     }
# }</script><script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type": "LocalBusiness",
#     "name": "I. T. Vedant Education Pvt. Ltd.",
#     "image": "https://www.itvedant.com/images/logo.svg",
#     "@id": "https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&utm_medium=DSDA10_Offline&utm_campaign=Generic_Ahmedabad&utm_term=it%20training%20institute&utm_location=9061748&utm_device=c&utm_adgroupid=195200758979&utm_network=g&gad_source=1&gad_campaignid=22877782544&gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE",
#     "url": "https://www.itvedant.com/",
#     "telephone": "9205004404",
#     "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "303, 3rd Floor, Iscon Avenue, Navrangpura, C G Road, Opp. Choice Restaurant\r\n Above Kundanlal Jewellers, Ahmedabad, 380009",
#         "addressLocality": "ahmedabad",
#         "postalCode": "380009",
#         "addressCountry": "IN"
#     },
#     "geo": {
#         "@type": "GeoCoordinates",
#         "latitude": "23.035769",
#         "longitude": "72.561067"
#     },
#     "openingHoursSpecification": {
#         "@type": "OpeningHoursSpecification",
#         "dayOfWeek": [
#             "Monday",
#             "Tuesday",
#             "Wednesday",
#             "Thursday",
#             "Friday",
#             "Saturday",
#             "Sunday"
#         ],
#         "opens": "09:00",
#         "closes": "20:30"
#     },
#     "sameAs": [
#         "https://www.facebook.com/itvedant",
#         "https://www.instagram.com/itvedant",
#         "https://www.youtube.com/channel/UCZ-3vm-2NwZiGpFm5TV8lRA",
#         "https://www.linkedin.com/company/itvedant",
#         "https://www.itvedant.com/"
#     ],
#     "description": "Professional data science training institute in Ahmedabad. Data Science & Analytics with AI course & training in Ahmedabad. Certified & placed. Don't Miss Out!"
# }</script><!-- schema file data -->
# <!-- BEGIN: SMART POPUP -->
# <script>
#   const custom_base_url_link = "https://www.itvedant.com";
#   const custom_package = "";
#   const custom_form_name_list = '{"1":"course_selector_submit","2":"get_career_guidance_submit","3":"banner_download_brochure_submit","4":"section_download_brochure_submit","5":"banner_form_submit","6":"stats_inquire_now_submit","7":"inquire_footer_submit","8":"inquire_now_footer_submit","9":"course_download_brochure_submit","10":"certificate_inquire_now_submit","11":"career_report_submit","12":"placement_freecounseling_submit","13":"placement_date_request_submit","14":"hiring_partners_inquire_now_submit","15":"pay_fees_submit","16":"refer_n_earn_submit","17":"success_stories_inquire_now_submit","18":"success_stories_brochure_download_submit","19":"growth_inqiury_submit","20":"contact_us_submit","21":"recurring_popup_submit","22":"digi_marketing_banner_form_submit","23":"popup_form_placement_report_first_submit","24":"popup_form_placement_report_second_submit","25":"popup_form_placement_report_third_submit","26":"popup_form_resume_handbook_submit","27":"popup_form_discount_offer","28":"popup_form_emi","29":"popup_form_nearest_branch","30":"executive_program_form","31":"master_class_form","32":"book_my_seat_form","33":"dsda_nigeria_form","34":"no_email_personal_information_form","35":"no_email_download_brochure_form"}';
#   const custom_x = "/data-science-and-ai-in-ahmedabad";
#   const custom_bouchure_image_list = '{"index":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software-engineering":{"image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"digital-marketing":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-data-science-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"online-software-testing-course":{"image":"software-testing.webp","brochure_name":"st","alt":"software testing brochure"},"online-devops-with-aws-course":{"image":"","brochure_name":"","alt":""},"devops-with-aws-course":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"aws-azure-cloud-technology":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"data-science-and-ai":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"success-stories":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"placements":{"image":"career-books.webp","brochure_name":"career_report","alt":"itvedant brochure"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"data-science-masterclass-for-executives":{"image":"home_page.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"python-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"data-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"corporat ...
#   const custom_course = "data-science-and-ai";
#   const custom_page = "";
# </script>
# <!-- END: SMART POPUP -->
# <!-- Global image load fallback: any image that fails to load shows placeholder (incl. dynamically added) -->
# <script>
# (function() {
#   var base = (typeof path !== 'undefined' && path) ? path : (typeof custom_base_url_link !== 'undefined' && custom_base_url_link ? custom_base_url_link : '');
#   var fallbackUrl = base ? (String(base).replace(/\/$/, '') + '/images/contact/blank.svg') : '/images/contact/blank.svg';
#   function applyFallbackToImg(img) {
#     if (img && img.nodeName === 'IMG' && !img.hasAttribute('onerror')) {
#       img.setAttribute('onerror', "this.onerror=null;this.src='" + fallbackUrl.replace(/'/g, "\\'") + "';");
#     }
#   }
#   function applyFallback() {
#     document.querySelectorAll('img').forEach(applyFallbackToImg);
#   }
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', function() {
#       applyFallback();
#       var observer = new MutationObserver(function(mutations) {
#         mutations.forEach(function(m) {
#           if (m.addedNodes && m.addedNodes.length) {
#             for (var i = 0; i < m.addedNodes.length; i++) {
#               var n = m.addedNodes[i];
#               if (n.nodeType === 1) {
#                 if (n.tagName === 'IMG') applyFallbackToImg(n);
#                 if (n.querySelectorAll) n.querySelectorAll('img').forEach(applyFallbackToImg);
#               }
#             }
#           }
#         });
#       });
#       observer.observe(document.body, { childList: true, subtree: true });
#     });
#   } else {
#     applyFallback();
#   }
# })();
# </script>
# </body>
# </html><script>
#   (function() {
#     var currentPath = (window.location.pathname || '').toLowerCase();
#     if (currentPath.indexOf('/data-science-and-ai-in-nigeria') === -1 && currentPath.indexOf('/data-science-and-ai-in-kenya') === -1 && currentPath.indexOf('/data-science-and-ai-in-tanzania') === -1) return;
#     var customPopupImage = "";
#     var customPopupBrochureName = "";
#     if (!customPopupImage && !customPopupBrochureName) return;
#     var selector = '.trigger-custom-modal[data-modal-link="templates/popups/default/forms/popup-download-brochure.php"], .trigger-custom-modal[data-modal-link="/templates/popups/default/forms/popup-download-brochure.php"]';
#     var buttons = document.querySelectorAll(selector);
#     buttons.forEach(function(button) {
#       if (customPopupImage) button.setAttribute('data-custom-popup-image', customPopupImage);
#       if (customPopupBrochureName) button.setAttribute('data-custom-popup-brochure-name', customPopupBrochureName);
#     });
#   })();
# </script>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org/",
#       "@type": "Product",
#       "name": "Data Science & Analytics with AI Course",
#       "image": "https://www.itvedant.com/images/location/thane1.webp",
#       "description": "An Industry-aligned Data Science & Analytics with AI course with 100% Job Guarantee !!",
#       "brand": {
#         "@type": "Brand",
#         "name": "Itvedant Education Pvt. Ltd"
#       },
#       "offers": {
#         "@type": "Offer",
#         "url": "https://www.itvedant.com/data-science-and-ai",
#         "priceCurrency": "INR",
#         "price": "0",
#         "priceValidUntil": "2040-01-01",
#         "availability": "https://schema.org/LimitedAvailability",
#         "itemCondition": "https://schema.org/NewCondition"
#       },
#       "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "4",
#         "bestRating": "5",
#         "worstRating": "0",
#         "ratingCount": "1",
#         "reviewCount": "1"
#       },
#       "review": {
#           "@type": "Review",
#           "name": "Ashwini Ingle",
#           "reviewBody": "Very nice teaching skills Cooperative faculties Asif sir was really helpful",
#           "reviewRating":
#           {
#             "@type": "Rating",
#             "ratingValue": "4",
#             "bestRating": "5",
#             "worstRating": "0"
#           },
#           "datePublished": "2023-03-11",
#           "author": { "@type": "Person", "name": "Ashwini Ingle" },
#           "publisher": { "@type": "Organization", "name": "Ashwini Ingle" }
#       }
#     }
#     </script>

# %%
print(itt.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- title -->
#   <!-- google bot -->
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=0" /> -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <!-- page specific meta tags
#    -->
#    <!-- favicon -->
#    <link href="https://www.itvedant.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <!-- meta info -->
#    <title>
#     Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad
#    </title>
#    <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" name="description">
#     <meta content="data science course in ahmedabad, data analytics course in ahmedabad" name="keywords"/>
#     <link href="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" rel="canonical"/>
#     <!-- open graph tags -->
#     <meta content="Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad" property="og:title"/>
#     <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" property="og:description"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" property="og:url"/>
#     <meta content="https://www.itvedant.com/images/footer-logo.png" property="og:image"/>
#     <!-- Twitter Meta Tags -->
#     <meta content="summary" name="twitter:card"/>
#     <meta content="www.itvedant.com" property="twitter:domain"/>
#     <meta content="@itvedant" name="twitter:site">
#      <meta content="https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&amp;utm_medium=DSDA10_Offline&amp;utm_campaign=Generic_Ahmedabad&amp;utm_term=it%20training%20institute&amp;utm_location=9061748&amp;utm_device=c&amp;utm_adgroupid=195200758979&amp;utm_network=g&amp;gad_source=1&amp;gad_campaignid=22877782544&amp;gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&amp;gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE" property="twitter:url"/>
#      <meta content="Job-Oriented Data Science Course &amp; Classes with AI Analytics in Ahmedabad" name="twitter:title"/>
#      <meta content="Professional data science training institute in Ahmedabad. Data Science &amp; Analytics with AI course &amp; training in Ahmedabad. Certified &amp; placed. Don't Miss Out!" name="twitter:description"/>
#      <meta content="https://www.itvedant.com/images/footer-logo.png" name="twitter:image"/>
#      <link href="https://connect.facebook.net" rel="preconnect"/>
#      <link href="https://connect.facebook.net" rel="dns-prefetch"/>
#      <script>
#       function loadScript(url) {
#     const script = document.createElement('script');
#     script.src = url;
#     document.head.append(script);
#     return script;
#   }
#
#   function loadScriptDelay(url) {
#     // Use setTimeout with 0 delay to run the script loading after the main thread is free
#     setTimeout(function() {
#       const script = document.createElement('script');
#       script.src = url;
#       document.head.append(script);
#       return script;
#     }, 5000);
#   }
#
#   function loadScriptAsync(url) {
#     return new Promise((resolve, reject) => {
#       const script = document.createElement('script');
#
#       script.src = url;
#
#       script.onload = () => resolve();
#       script.onerror = (error) => reject(error);
#
#       document.body.append(script);
#     });
#   }
#
#   document.addEventListener('DOMContentLoaded', async function() {
#     await loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js');
#         loadScript('https://www.itvedant.com/js/coursewise-video-min.js?v=1782927482');
#
#     await loadScriptAsync('https://www.itvedant.com/slick/slick.min.js?v=1782927482');
#     await loadScriptAsync('https://www.itvedant.com/dest/js/main-min.js?v=1782927482');
#
#
#     loadScript('https://www.itvedant.com/dest/js/form-min.js?v=1787845438');
#     // loadScript('<?//= $path ?>/js/popup-config-min.js');
#
#     // loadScript('<?//= $path ?>/js/right-menu.js');
#     loadScript('https://www.itvedant.com/bootstrap/js/bootstrap.min.js');
#     loadScript('https://www.itvedant.com/bootstrap/js/lazysizes.min.js');
#
#     //load google location js
#     loadScript('https://www.itvedant.com/js/google-location.js?v=1788453813');
#
#     // $('.rotating-menu-arrow').click(function() {
#     //   $(this).find(".menu-rotate").toggleClass('rotating-arrow-animation');
#     // });
#
#     $('.menu-item').click(function(){
#       if(!($(this).hasClass('active'))){
#
#         $(this).find(".menu-rotate").addClass('rotating-arrow-animation');
#       }
#       else{
#         $(this).find(".menu-rotate").removeClass('rotating-arrow-animation');
#       }
#
#     });
#
#
#         // loadScriptDelay('https://www.itvedant.com/js/batch-countdown.js');
#         //   loadScript('https://www.itvedant.com/js/batch-countdown.js');
#     //
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         loadScript('https://www.itvedant.com/js/students-reviews-min.js?v=1782927482');
#     loadScript('https://www.itvedant.com/dest/js/trust-component-min.js?v=1782927482');
#
#
#           loadScript('https://www.itvedant.com/dest/js/industry-project-min.js?v=1782927482');
#
#
#
#
#
#
#
#
#
#
#
#
#           });
#      </script>
#      <!-- <script src="<? //= $path
#                     ?>/bootstrap/cached-webpgr.min.js"></script> -->
#      <script>
#       switch(window.location.host)
#             {
#               case "localhost"        : path = "http://localhost/itvedant-website-2024"; break;
#               case "itvedant.test"    : path = "http://itvedant.test"; break;
#               case "www.itvedant.test": path = "http://www.itvedant.test"; break;
#               case "aws.itvedant.com" : path = "https://aws.itvedant.com"; break;
#               default                 : path = "https://www.itvedant.com";
#             }
#
#             var site_url                = "https://www.itvedant.com";
#             var api_url                 = "https://api.itvedant.com/index.php";
#             var sms_url                 = "https://www.itvedant.com/itv_forms";
#             var site_key                = "6LdsStQqAAAAAEV4rVCPjh76nujlzPMNxZTVTTUc";
#             var ip_address                = "20.0.1.49";
#             var user_agent                = "python-requests/2.32.3";
#             var form_name_list          = {"1":"course_selector_submit","2":"get_career_guidance_submit","3":"banner_download_brochure_submit","4":"section_download_brochure_submit","5":"banner_form_submit","6":"stats_inquire_now_submit","7":"inquire_footer_submit","8":"inquire_now_footer_submit","9":"course_download_brochure_submit","10":"certificate_inquire_now_submit","11":"career_report_submit","12":"placement_freecounseling_submit","13":"placement_date_request_submit","14":"hiring_partners_inquire_now_submit","15":"pay_fees_submit","16":"refer_n_earn_submit","17":"success_stories_inquire_now_submit","18":"success_stories_brochure_download_submit","19":"growth_inqiury_submit","20":"contact_us_submit","21":"recurring_popup_submit","22":"digi_marketing_banner_form_submit","23":"popup_form_placement_report_first_submit","24":"popup_form_placement_report_second_submit","25":"popup_form_placement_report_third_submit","26":"popup_form_resume_handbook_submit","27":"popup_form_discount_offer","28":"popup_form_emi","29":"popup_form_nearest_branch","30":"executive_program_form","31":"master_class_form","32":"book_my_seat_form","33":"dsda_nigeria_form","34":"no_email_personal_information_form","35":"no_email_download_brochure_form"};
#             var compaign_branch_list    = {"thane":"1","andheri":"2","eclass":"3","navimumbai":5,"pune":6,"bengaluru":"7","chennai":"8","hyderabad":"9","borivali":"11","delhi":"12","pimple":"13","pimpri":"13","pimprichinchwad":"13","pimpri-chinchwad":"13","katraj":"14","kalyan":"15","dadar":"16","nagpur":"17","ahmedabad":"18","lucknow":"20","nashik":"21","e-class":"3","headoffice":"4","head-office":"4","vashi":"5","fcroad":"6","fc-road":"6","bangalore":"7","noida":"22","africa":"23","vasai":"25"};
#             var course_packages         = {"\/aws-azure-cloud-technology":"Master In AWS Cloud Technology","\/data-science-and-ai":"Master in Data Science & Analytics with Artificial Intelligence","\/python-full-stack-developer-course":"Master in Full Stack Web Development with Python","\/java-full-stack-developer-course":"Master in Full Stack Web Development with Java","\/data-software-engineering":"Masters in Data Software Engineering","\/digital-marketing-course":"Master in Digital Marketing with AI","\/contact":"","\/itvedant-website":"","\/refer-and-earn":"","\/enrol":"","www.itvedant.com":""};
#             var brochure_list           = {"default":{"modal_title":"Download Brochure","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software":{"modal_title":"Download Brochure","image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"aws-technology":{"modal_title":"Download Brochure","image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"digital-marketing":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"data-science":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"placement-report":{"modal_title":"Download Placement Report","image":"career-books.webp","brochure_name":"career_report","alt":"career_report"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"python-course":{"image":"home_page.webp","brochure_name":"python_modular","alt":"itvedant brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant brochure"},"data-analytics-course":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"modal_title":"Download Brochure","image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"modal_title":"Download Brochure","image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"modal_title":"Download Brochure","image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"modal_title":"Download Brochure","image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"success-stories":{"modal_title":"Download Success Stories","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"full-stack-course":{"modal_title":"Download Brochure","image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"ml-course":{"modal_title":"Download Brochure","image":"data-science-and-ai.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant machine learning brochure"},"social-media-marketing-course":{"modal_title":"Download Brochure","image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"sql-course":{"modal_title":"Download Brochure","image":"ful ...
#             var bouchure_image_list     =  {"index":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software-engineering":{"image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"digital-marketing":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-data-science-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"online-software-testing-course":{"image":"software-testing.webp","brochure_name":"st","alt":"software testing brochure"},"online-devops-with-aws-course":{"image":"","brochure_name":"","alt":""},"devops-with-aws-course":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"aws-azure-cloud-technology":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"data-science-and-ai":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"success-stories":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"placements":{"image":"career-books.webp","brochure_name":"career_report","alt":"itvedant brochure"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"data-science-masterclass-for-executives":{"image":"home_page.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"python-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"data-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"cor ...
#             var custom_new_bouchure_image_list     =  {"default":{"modal_title":"Download Brochure","image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"masters_in_data_science_with_ai_and_aws.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"master_certification_in_full_stack_development.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant brochure"},"master_in_java.pdf":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development.pdf":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"master_in_aws_azure_cloud_technology.pdf":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"digital_marketing.pdf":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"executive.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"career_report.pdf":{"image":"career-books.webp","brochure_name":"career_report","alt":"career report"},"executive_program_devops_with_aws.pdf":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"investment_banking_with_ai.pdf":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking with ai brochure"},"master_in_software_testing_with_ai.pdf":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing with ai brochure"},"masters_in_data_science_with_ai_nigeria.pdf":{"image":"executive-thumbnail.jpg","brochure_name":"masters_in_data_science_with_ai_nigeria","alt":"itvedant data science and ai brochure"}};
#             var current_branch_id       = "18";
#             var form_current_branch_id  = "18";
#             var page                    = "";
#             var course                  = "data-science-and-ai";
#             var is_ipinfo               = 0;
#             var branch_info             = {"thane":{"id":1,"name":"Thane","icon":"thane.svg","icon_alt":"Itvedant Thane Branch","address":"2nd Floor, Ishaan Arcade-1, Opposite Gaondevi Mandir, Above Canara bank, Gokhale Road,Landmark: 3 Buildings after McDonalds, Thane (West)","pincode":"400602","geolocation":{"lat":"19.187644486358995","lng":"72.9738175"},"time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"wa_contact":9205004404,"thumbnail_imgs":["thane1.webp","thane2.webp","thane3.webp","thane4.webp"],"thumbnail_imgs_alt":["Itvedant Thane reception - 2","Itvedant Thane reception - 1","Itvedant Thane reception - 3","Itvedant Thane Cafeteria"],"imgs":["thane1.webp","thane2.webp","thane3.webp","thane4.webp","thane5.webp","thane6.webp"],"imgs_text":["Sit Out Area At Thane Branch"," Campus Placement drive at Thane branch","Classroom training at Thane branch","Campus Placement drive at Thane branch"," Career Counselling session at Thane branch","Classroom training at Thane branch"],"imgs_alt":["Sit Out Area At Thane Branch"," Campus Placement drive at Thane branch","Classroom training at Thane branch","Campus Placement drive at Thane branch"," Career Counselling session at Thane branch","Classroom training at Thane branch"],"direction":"https:\/\/g.page\/Itvedant?share","country":"IN"},"andheri":{"id":2,"name":"Andheri","icon":"andheri.svg","icon_alt":"Itvedant Andheri Branch","address":"1st Floor Bina Apartments,Beside Ganpati Mandir,Opposite Arasa Hotel, Near Andheri Metro Station, Andheri (East), Mumbai","pincode":"400069","time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"geolocation":{"lat":"19.120030187551304","lng":"72.85017889999999"},"wa_contact":9205004404,"thumbnail_imgs":["andheri1.webp","andheri2.webp","andheri3.webp","andheri4.webp"],"thumbnail_imgs_alt":["Itvedant Andheri reception - 1","Itvedant Andheri elevator","Itvedant Andheri waiting area-1","Itvedant Andheri waiting area-2"],"imgs":["andheri1.webp","andheri2.webp","andheri3.webp","andheri4.webp","andheri5.webp","andheri6.webp"],"imgs_text":["Reception area at Andheri branch","Itvedant Andheri Elevator","Sit Out area at Andheri branch"," Classroom training at Andheri branch","Classroom training at Andheri branch","Learners Facilitation At Andheri Branch"],"imgs_alt":["Reception area at Andheri branch","Itvedant Andheri Elevator","Sit Out area at Andheri branch"," Classroom training at Andheri branch","Classroom training at Andheri branch","Learners Facilitation At Andheri Branch"],"direction":"https:\/\/g.page\/Itvedant-andheri?share","country":"IN"},"borivali":{"id":11,"name":"Borivali","icon":"borivali.svg","icon_alt":"Itvedant Borivali Branch","address":"1st Floor, Bhandarkar Bhavan, S.V. Road Court Lanes, Near Police Station, Opp. Borivali Railway Station, Borivali West, Mumbai, Maharashtra","pincode":"400092","time":{"open":"9am","close":"9pm","working_days":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]},"geolocation":{"lat":"19.23006337498649","lng":"72.85586843752289"},"wa_contact":9205004404,"thumbnail_imgs":["borivali1.webp","borivali2.webp","borivali3.webp","borivali4.webp"],"thumbnail_imgs_alt":["Itvedant Borivali Reception-1","Itvedant Borivali Classroom - 1","Itvedant Borivali Counselling Cabin-1","Itvedant Borivali Reception-2","Itvedant Borivali Counselling Cabin-2","Itvedant Borivali Washroom"],"imgs":["borivali1.webp","borivali2.webp","borivali3.webp","borivali4.webp","borivali5.webp","borivali6.webp"],"imgs_text":["Classroom training at Borivali branch","Happy Learners of Borivali branch","Classroom training at Borivali branch","  Sit Out Area At Borivali Branch","Career Counselling session at Borivali branch"," Career Counselling session at Borivali branch"],"imgs_alt":["Classroom training at Borivali branch","Happy Learners of Borivali branch","Classroom training at Bor ...
#             var enrol_branch_list       = {"1":"thane","2":"andheri","3":"eclass","5":"navi-mumbai","6":"pune","7":"bengaluru","8":"chennai","9":"hyderabad","11":"borivali","12":"delhi","13":"pimpri-chinchwad","14":"katraj","15":"kalyan","16":"dadar","17":"nagpur","18":"ahmedabad","20":"lucknow","21":"nashik","4":"head-office","22":"noida","23":"africa","25":"vasai"};
#             var branch_name_list    = {"1":"Thane","2":"Andheri","3":"E-Class","4":"Head Office","5":"Vashi","6":"FC Road","7":"Bengaluru","8":"Chennai","9":"Hyderabad","11":"Borivali","12":"Delhi","13":"Pimpri","14":"Katraj","15":"Kalyan","16":"Dadar","17":"Nagpur","18":"Ahmedabad","20":"Lucknow","21":"Nashik","22":"Noida","23":"Africa","25":"Vasai"};
#             window.js_branch_data   = {"js_locations":[{"name":"1","lat":"19.187644486358995","lng":"72.9738175","state":"Central"},{"name":"2","lat":"19.120030187551304","lng":"72.85017889999999","state":"Western"},{"name":"5","lat":"19.06652154674476","lng":"72.9990716711645","state":"Central"},{"name":"7","lat":"12.916461604745717","lng":"77.61119818650646","state":"South"},{"name":"8","lat":"13.084797955268899","lng":"80.21185888465804","state":"South"},{"name":"9","lat":"17.498283088472903","lng":"78.39012807116451","state":"South"},{"name":"11","lat":"19.23006337498649","lng":"72.85586843752289","state":"Western"},{"name":"12","lat":"28.571474564873693","lng":"77.21968096192246","state":"North"},{"name":"14","lat":"18.450154920279193","lng":"73.85778906931611","state":"Pune"},{"name":"15","lat":"19.236793549985745","lng":"73.1292745","state":"Central"},{"name":"16","lat":"19.01675523226402","lng":"72.8439855","state":"Western"},{"name":"17","lat":"21.13951025748816","lng":"79.06024855767097","state":"Pune"},{"name":"18","lat":"23.035768667229622","lng":"72.56106715120089","state":"Western"},{"name":"20","lat":"26.850301903455694","lng":"80.94334206734158","state":"North"},{"name":"21","lat":"20.00667278356107","lng":"73.75947534232903","state":"Central"},{"name":"22","lat":"28.62801504462737","lng":"77.37608371349255","state":"North"},{"name":"23","lat":"6.621723592983252","lng":"3.3526240992236267","state":"Overseas"},{"name":"25","lat":"19.383602493539886","lng":"72.83118418654539","state":"Western"}],"js_names":{"1":"Thane","2":"Andheri","3":"E-Class","4":"Head Office","5":"Vashi","6":"FC Road","7":"Bengaluru","8":"Chennai","9":"Hyderabad","11":"Borivali","12":"Delhi","13":"Pimpri","14":"Katraj","15":"Kalyan","16":"Dadar","17":"Nagpur","18":"Ahmedabad","20":"Lucknow","21":"Nashik","22":"Noida","23":"Africa","25":"Vasai"},"campaign_map":{"thane":"thane","andheri":"andheri","e-class":"e-class","headoffice":"head-office","head-office":"head-office","vashi":"vashi","fcroad":"fc-road","fc-road":"fc-road","bengaluru":"bengaluru","bangalore":"bengaluru","chennai":"chennai","hyderabad":"hyderabad","borivali":"borivali","delhi":"delhi","pimpri":"pimpri","pimple":"pimpri","katraj":"katraj","kalyan":"kalyan","dadar":"dadar","nagpur":"nagpur","ahmedabad":"ahmedabad","lucknow":"lucknow","nashik":"nashik","noida":"noida","africa":"africa","vasai":"vasai"}};
#             var google_api_key          = "AIzaSyC9G-faB5BCN6DsJxpgy-ZinWJG0R_nhLE";
#             var cookie_expiry_minutes   = 43200;
#             var TRACKING_CONFIG = {
#                 GA4: "G-VYPTR9R8L7",
#                 AW_LEAD: "AW-826880244/52oZCPibipYBEPThpIoD",
#                 AW_MOBILE: "AW-826880244/X1SICIGzofAaEPThpIoD",
#                 AW_CONTACT: "AW-826880244/4SG7CNXTyIccEPThpIoD"
#             };
#             window.INTL_MOBILE_RULE = null;
#      </script>
#      <script>
#       var current_branch_id = 18;  var form_current_branch_id = 18;
#      </script>
#      <script>
#       window.dataLayer = window.dataLayer || [];
#       dataLayer.push({
#         'gtm.blocklist': ['.view-batch-details-click']
#       });
#      </script>
#      <!-- CSS files -->
#      <link as="style" href="https://www.itvedant.com/bootstrap/css/bootstrap.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <link as="style" href="https://www.itvedant.com/bootstrap/css/bootstrap-icons.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <link as="style" href="https://www.itvedant.com/slick/slick.min.css?v=1782927482" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <link as="style" href="https://www.itvedant.com/slick/slick-theme.min.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <link href="https://www.itvedant.com/dest/css/main.min.css?v=1787678638" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/our-upcoming-section.css?v=1788528877" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/course-curriculum.css?v=1782927482" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/wingz-section.css?v=1782927482" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/trainer-list.css?v=1787678638" rel="stylesheet"/>
#      <link as="style" href="https://www.itvedant.com/css/personal-coach.css?v=1782927482" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#      <noscript>
#       <link href="https://www.itvedant.com/css/personal-coach.css?v=1782927482" rel="stylesheet"/>
#      </noscript>
#      <link as="style" href="https://www.itvedant.com/css/batch-countdown.css" onload="this.onload=null;this.rel='stylesheet'" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/campus-placement-drive.css?v=1782927482" rel="stylesheet"/>
#      <!-- all popup css -->
#      <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/css/popup/popup-forms.css?v=1782927482"> -->
#      <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/templates/popups/default/css/popup-form-emi.css"> -->
#      <!-- <link rel="stylesheet" href="<? //php echo $path
#                                     ?>/templates/popups/default/css/popup-form-branches.css"> -->
#      <script>
#       ! function(e) {
#       "function" == typeof define && define.amd ? define(e) : e()
#     }(function() {
#       var e, t = ["scroll", "wheel", "touchstart", "touchmove", "touchenter", "touchend", "touchleave", "mouseout", "mouseleave", "mouseup", "mousedown", "mousemove", "mouseenter", "mousewheel", "mouseover"];
#       if (function() {
#           var e = !1;
#           try {
#             var t = Object.defineProperty({}, "passive", {
#               get: function() {
#                 e = !0
#               }
#             });
#             window.addEventListener("test", null, t), window.removeEventListener("test", null, t)
#           } catch (e) {}
#           return e
#         }()) {
#         var n = EventTarget.prototype.addEventListener;
#         e = n, EventTarget.prototype.addEventListener = function(n, o, r) {
#           var i, s = "object" == typeof r && null !== r,
#             u = s ? r.capture : r;
#           (r = s ? function(e) {
#             var t = Object.getOwnPropertyDescriptor(e, "passive");
#             return t && !0 !== t.writable && void 0 === t.set ? Object.assign({}, e) : e
#           }(r) : {}).passive = void 0 !== (i = r.passive) ? i : -1 !== t.indexOf(n) && !0, r.capture = void 0 !== u && u, e.call(this, n, o, r)
#         }, EventTarget.prototype.addEventListener._original = e
#       }
#     });
#
#     /* document.addEventListener('DOMContentLoaded', async function() {
#       const head  = document.getElementsByTagName('head')[0];
#       const link  = document.createElement('link');
#       link.rel  = 'stylesheet';
#       link.type = 'text/css';
#       link.href = 'https://www.itvedant.com/bootstrap/css/bootstrap-icons.min.css';
#       link.media = 'all';
#       head.appendChild(link);
#     }); */
#      </script>
#      <!-- Conversion Tracking -->
#      <!-- Preconnect -->
#      <link href="https://www.googletagmanager.com" rel="preconnect"/>
#      <link href="https://connect.facebook.net" rel="preconnect"/>
#      <!-- Google Tag -->
#      <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-YVPTR9RBL7">
#      </script>
#      <script>
#       window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config','G-YVPTR9RBL7');
# gtag('config','AW-826880244');
#      </script>
#      <!-- Meta Pixel -->
#      <script>
#       !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init',"27800555899562405");
# fbq('track','PageView');
#      </script>
#      <link href="https://www.itvedant.com/css/placement.css?v=1782927482" rel="stylesheet"/>
#      <link href="https://www.itvedant.com/css/new-wingz-component.css?v=1782927482" rel="stylesheet"/>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- call fix for Web -->
#   <div class="webfix d-none d-md-block">
#   </div>
#   <div class="webfix d-none d-md-block">
#   </div>
#   <div class="main">
#    <nav class="p-4">
#     <div class="container">
#      <div class="row mobile-logo-align">
#       <div class="col-xl-7 col-lg-7 col-md-6 col-sm-6 col-6 d-flex align-items-center p-0">
#        <a href="https://www.itvedant.com">
#         <img alt="Itvedant" fetchpriority="high" height="100%" src="https://www.itvedant.com/images/itv-logo.svg" width="auto"/>
#        </a>
#        <div class="dropdown-left" id="course-menu">
#         <ul>
#          <li>
#           <a class="exp text-decoration-none" href="#">
#            Explore Courses
#            <img alt="Explore Courses icon" loading="lazy" src="https://www.itvedant.com/images/rotation.svg"/>
#           </a>
#           <div class="itv-menu-container main-menu-divs position-absolute" style="display: none;">
#            <div class="itv-menu-sidebar d-none">
#             <div>
#              <div class="itv-menu-tab itv-menu-active" data-target="itv-menu-freshers">
#               For Freshers
#              </div>
#              <div class="itv-menu-tab d-flex justify-content-between" data-target="professionals">
#               For Working Professionals
#              </div>
#             </div>
#             <div>
#              <p class="talk-expert-menu">
#               <span>
#                Looking for Guidance ?
#               </span>
#               <a class="talk-button talk-with-guide text-dark" href="tel:9205004404" target="_blank">
#                Talk To Career Guide
#                <i class="bi bi-telephone text-dark pl-2">
#                </i>
#               </a>
#              </p>
#             </div>
#            </div>
#            <div class="itv-menu-content">
#             <div class="itv-menu-course-group" id="itv-menu-freshers" style="display: block;">
#              <a class="text-decoration-none" href="https://www.itvedant.com/data-science-and-ai">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Data Science &amp; Analytics with AI
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/full-stack-developer-course">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Full Stack Development
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/devops-with-aws-course">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    DevOps with AWS
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/digital-marketing-course">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Digital Marketing with AI
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/investment-banking-course">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Investment Banking with AI
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/software-testing-course">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Software Testing With AI
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <a class="text-decoration-none" href="https://www.itvedant.com/cyber-security-ethical-hacking-with-ai-course ">
#               <div class="course-card row">
#                <div class="col-md-10">
#                 <div class="course-row">
#                  <div>
#                   <p class="course-title">
#                    Cyber Security &amp; Ethical Hacking with AI
#                   </p>
#                   <p class="course-duration">
#                    <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-time.svg"/>
#                    Duration : 6 Months
#                   </p>
#                  </div>
#                 </div>
#                </div>
#                <div class="col-md-2 d-flex align-items-center">
#                 <span class="course-arrow">
#                  <img alt="green arrow" loading="lazy" src="https://www.itvedant.com/images/icon/green-arrow.svg"/>
#                 </span>
#                </div>
#               </div>
#              </a>
#              <div>
#               <p class="talk-expert-menu">
#                <span>
#                 Looking for Guidance ?
#                </span>
#                <a class="talk-button talk-with-guide text-dark" href="tel:9205004404" target="_blank">
#                 Talk To Career Guide
#                 <i class="bi bi-telephone text-dark pl-2">
#                 </i>
#                </a>
#               </p>
#              </div>
#             </div>
#             <div class="itv-menu-course-group" id="professionals">
#              <div class="row">
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="crm d-none" data-target="#course-selector" data-toggle="modal" id="course_selector_form_click">
#            Course Selector
#            <img alt="" loading="lazy" src="https://www.itvedant.com/images/path.svg"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="col-xl-5 col-lg-5 col-md-6 col-sm-6 col-6 d-flex justify-content-end">
#        <div class="right_menu">
#         <ul>
#          <li>
#           <button class="c-guide trigger-custom-modal" data-custom-popup-in-popup-flow="true" data-modal-link="https://www.itvedant.com/templates/popups/default/forms/popup-career-guidance.php" data-target="#custom-career-guidance-modal" data-toggle="modal" itv-btn-type="get_career_guidance_submit">
#            Get Career Guidance
#            <img alt="arrow" loading="lazy" src="https://www.itvedant.com/images/career-guide-icon.svg"/>
#           </button>
#          </li>
#         </ul>
#        </div>
#        <div class="navbars">
#         <button class="c-guide mr-4 cg-mobile trigger-custom-modal" data-custom-popup-in-popup-flow="true" data-modal-link="https://www.itvedant.com/templates/popups/default/forms/popup-career-guidance.php" data-target="#custom-career-guidance-modal" data-toggle="modal" itv-btn-type="get_career_guidance_submit">
#          <img alt="arrow" fetchpriority="high" src="https://www.itvedant.com/images/career-guide-icon.svg"/>
#         </button>
#         <span class="open-menu" fetchpriority="high">
#          <svg height="16" width="24" xmlns="http://www.w3.org/2000/svg">
#           <g fill="#252a32" fill-rule="evenodd">
#            <path d="M0 0h24v2H0zM0 7h24v2H0zM0 14h24v2H0z">
#            </path>
#           </g>
#          </svg>
#         </span>
#         <div class="menu-wrapper">
#          <ul class="menu">
#           <li class="menu-block">
#            <span class="close-menu">
#             <svg height="20" width="20" xmlns="http://www.w3.org/2000/svg">
#              <path d="M17.778.808l1.414 1.414L11.414 10l7.778 7.778-1.414 1.414L10 11.414l-7.778 7.778-1.414-1.414L8.586 10 .808 2.222 2.222.808 10 8.586 17.778.808z" fill="#252a32" fill-rule="evenodd">
#              </path>
#             </svg>
#             <strong class="closing-align">
#             </strong>
#            </span>
#           </li>
#           <li class="menu-item has-collapsible active" id="query2">
#            <a class="p-0 cursor-pointer">
#             <span class="rotating-menu-arrow" style="padding: 0 1rem;">
#              All Courses
#              <svg class="bi bi-chevron-right" fill="currentColor" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path d="M4.646 1.646a.5.5 0 0 1 .708 0l6 6a.5.5 0 0 1 0 .708l-6 6a.5.5 0 0 1-.708-.708L10.293 8 4.646 2.354a.5.5 0 0 1 0-.708z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <ul class="menu-child" id="course2">
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/data-science-and-ai">
#               Data Science &amp; Analytics with AI
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/full-stack-developer-course">
#               Full Stack Development
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/devops-with-aws-course">
#               DevOps with AWS
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/digital-marketing-course">
#               Digital Marketing with AI
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/investment-banking-course">
#               Investment Banking with AI
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/software-testing-course">
#               Software Testing With AI
#              </a>
#             </li>
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/cyber-security-ethical-hacking-with-ai-course ">
#               Cyber Security &amp; Ethical Hacking with AI
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item has-collapsible cursor-pointer d-none">
#            <a class="common-side-txt rotating-menu-arrow" id="query3">
#             For Working Professionals
#             <svg class="bi bi-chevron-right" fill="currentColor" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#              <path d="M4.646 1.646a.5.5 0 0 1 .708 0l6 6a.5.5 0 0 1 0 .708l-6 6a.5.5 0 0 1-.708-.708L10.293 8 4.646 2.354a.5.5 0 0 1 0-.708z" fill-rule="evenodd">
#              </path>
#             </svg>
#            </a>
#            <ul class="menu-child">
#             <li class="menu-child-item">
#              <a href="https://www.itvedant.com/devops-with-aws-course">
#               DevOps with AWS
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="menu-item">
#            <a class="menu-link" href="https://www.itvedant.com/placements">
#             Placements
#            </a>
#           </li>
# ...
#        <input id="schedule_form_inquiry_name" type="hidden"/>
#        <div class="main-card-padd mt-4">
#         <button class="schedule-btn bg-black-color w-100 trigger-form-submission" id="schedule2-btnn" type="button">
#          Schedule
#         </button>
#         <!-- onclick="submitFormsByType({ event: event, formTypeName: 'FORM_TYPE_SCHEDULE_VISIT', formIdName: 'schedule_form', formModalIdName: 'popup-form-placement-report-first-modal' })" -->
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="modal-content schedule-card" id="schedule-3">
#      <div class="modal-header align-items-center justify-content-start">
#       <img alt="" class="icon-align-schedule lazyload" data-src="https://www.itvedant.com/images/contact/schedule/right-arrow.svg" loading="lazy"/>
#       <h2 class="modal-title schedule-heading schedule-visit-validd" id="schedule-visit-heading">
#        Visit Successfully Scheduled
#       </h2>
#       <button aria-label="Close" class="close schedule-close" data-dismiss="modal" type="button">
#        <img alt="" src="https://www.itvedant.com/images/cross.svg"/>
#       </button>
#      </div>
#      <div class="modal-body bg-lightblue watch-heading">
#       <h3>
#        Get ready to meet our Expert at the Branch for Personalised Career Guidance!
#       </h3>
#       <div class="student-brochure-button">
#        <a class="ml-0 brochure-download-modal popup-brochure-form-btn-type" href="tel:9205004404">
#         <img alt="Talk to Career Guide" class="ls-is-cached lazyloaded" height="100%" loading="lazy" src="https://www.itvedant.com/images/mob-call.svg" style="padding-right: 0.5rem; height: 18px;" width="auto">
#          Talk to Career Guide
#         </img>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- schedule end here -->
#   <div aria-hidden="true" aria-labelledby="exampleModalCenterTitle" class="modal z-index-popup fade" id="placementModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-dialog-centered modal-lg" role="document">
#     <div class="modal-content schedule-card" id="placement-3">
#      <div class="modal-header align-items-center justify-content-center">
#       <strong style=" font-size:large;">
#        Thank you for your interest in candidates for employment
#       </strong>
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         <img alt="" loading="lazy" src="https://www.itvedant.com/images/cross.svg"/>
#        </span>
#       </button>
#      </div>
#      <div class="modal-body">
#       <h2 class="modal-title text-center">
#        <img alt="" class="icon-align-schedule lazyload d-block m-auto" data-src="https://www.itvedant.com/images/contact/schedule/right-arrow.svg" loading="lazy" width="50"/>
#        <p style=" font-size:small;">
#         A team member will contact you shortly to discuss your needs and assist in finding the right candidates from our pool.
#        </p>
#       </h2>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- schedule end here -->
#   <!-- LOAD MODALS -->
#   <div id="load-modal">
#   </div>
#   <div id="gtm-tiggers" style="position: fixed;
#     /* background: red; */
#     top: 0;
#     left: 0;
#     z-index: 1000000;">
#    <!-- MOBILE NO. GTM TRIGGER -->
#    <div class="mobile-number-valid d-none">
#    </div>
#    <div class="schedule-visit-valid d-none">
#    </div>
#    <div class="download-brochure-valid d-none">
#    </div>
#    <div class="book-my-seat-valid d-none">
#    </div>
#    <div class="success-monthly d-none">
#    </div>
#    <div class="success-onetime d-none">
#    </div>
#   </div>
#   <!-- LOAD MODALS -->
#   <!-- captcha pages -->
#   <!-- schema file data -->
#   <script type="application/ld+json">
#    {
#     "@context": "https://schema.org/",
#     "@type": "Product",
#     "name": "Data Science & Analytics with AI Course in Ahmedabad",
#     "image": "https://www.itvedant.com/images/logo.svg",
#     "description": "Professional data science training institute in Ahmedabad. Data Science & Analytics with AI course & training in Ahmedabad. Certified & placed. Don't Miss Out!",
#     "brand": {
#         "@type": "Brand",
#         "name": "Itvedant EDUCATION PVT. LTD."
#     },
#     "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "4.7",
#         "bestRating": "5",
#         "worstRating": "1",
#         "ratingCount": "1291"
#     }
# }
#   </script>
#   <script type="application/ld+json">
#    {
#     "@context": "https://schema.org",
#     "@type": "LocalBusiness",
#     "name": "I. T. Vedant Education Pvt. Ltd.",
#     "image": "https://www.itvedant.com/images/logo.svg",
#     "@id": "https://www.itvedant.com/data-science-and-ai-in-ahmedabad?utm_source=Google&utm_medium=DSDA10_Offline&utm_campaign=Generic_Ahmedabad&utm_term=it%20training%20institute&utm_location=9061748&utm_device=c&utm_adgroupid=195200758979&utm_network=g&gad_source=1&gad_campaignid=22877782544&gbraid=0AAAAADFJMPSgD3d0V-V88KzF9yH4jaiPV&gclid=CjwKCAjwwfnUBhAtEiwAfQpAYs2tVsLsZuPRoTIfm6GdXTRS_rN1apDKfYLjRdzo0kvSyX5CulpwvhoC7gcQAvD_BwE",
#     "url": "https://www.itvedant.com/",
#     "telephone": "9205004404",
#     "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "303, 3rd Floor, Iscon Avenue, Navrangpura, C G Road, Opp. Choice Restaurant\r\n Above Kundanlal Jewellers, Ahmedabad, 380009",
#         "addressLocality": "ahmedabad",
#         "postalCode": "380009",
#         "addressCountry": "IN"
#     },
#     "geo": {
#         "@type": "GeoCoordinates",
#         "latitude": "23.035769",
#         "longitude": "72.561067"
#     },
#     "openingHoursSpecification": {
#         "@type": "OpeningHoursSpecification",
#         "dayOfWeek": [
#             "Monday",
#             "Tuesday",
#             "Wednesday",
#             "Thursday",
#             "Friday",
#             "Saturday",
#             "Sunday"
#         ],
#         "opens": "09:00",
#         "closes": "20:30"
#     },
#     "sameAs": [
#         "https://www.facebook.com/itvedant",
#         "https://www.instagram.com/itvedant",
#         "https://www.youtube.com/channel/UCZ-3vm-2NwZiGpFm5TV8lRA",
#         "https://www.linkedin.com/company/itvedant",
#         "https://www.itvedant.com/"
#     ],
#     "description": "Professional data science training institute in Ahmedabad. Data Science & Analytics with AI course & training in Ahmedabad. Certified & placed. Don't Miss Out!"
# }
#   </script>
#   <!-- schema file data -->
#   <!-- BEGIN: SMART POPUP -->
#   <script>
#    const custom_base_url_link = "https://www.itvedant.com";
#   const custom_package = "";
#   const custom_form_name_list = '{"1":"course_selector_submit","2":"get_career_guidance_submit","3":"banner_download_brochure_submit","4":"section_download_brochure_submit","5":"banner_form_submit","6":"stats_inquire_now_submit","7":"inquire_footer_submit","8":"inquire_now_footer_submit","9":"course_download_brochure_submit","10":"certificate_inquire_now_submit","11":"career_report_submit","12":"placement_freecounseling_submit","13":"placement_date_request_submit","14":"hiring_partners_inquire_now_submit","15":"pay_fees_submit","16":"refer_n_earn_submit","17":"success_stories_inquire_now_submit","18":"success_stories_brochure_download_submit","19":"growth_inqiury_submit","20":"contact_us_submit","21":"recurring_popup_submit","22":"digi_marketing_banner_form_submit","23":"popup_form_placement_report_first_submit","24":"popup_form_placement_report_second_submit","25":"popup_form_placement_report_third_submit","26":"popup_form_resume_handbook_submit","27":"popup_form_discount_offer","28":"popup_form_emi","29":"popup_form_nearest_branch","30":"executive_program_form","31":"master_class_form","32":"book_my_seat_form","33":"dsda_nigeria_form","34":"no_email_personal_information_form","35":"no_email_download_brochure_form"}';
#   const custom_x = "/data-science-and-ai-in-ahmedabad";
#   const custom_bouchure_image_list = '{"index":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"data-software-engineering":{"image":"data-software-engineering.webp","brochure_name":"master_certification_in_data_software","alt":"itvedant data software engineering brochure"},"python-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-full-stack-developer-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"web-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"digital-marketing":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-digital-marketing-course":{"image":"digital-marketing.webp","brochure_name":"digital_marketing","alt":"itvedant digital marketing brochure"},"online-data-science-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"online-software-testing-course":{"image":"software-testing.webp","brochure_name":"st","alt":"software testing brochure"},"online-devops-with-aws-course":{"image":"","brochure_name":"","alt":""},"devops-with-aws-course":{"image":"devop-with-aws.webp","brochure_name":"executive_program_devops_with_aws","alt":"devops with aws brochure"},"aws-azure-cloud-technology":{"image":"devop-with-aws.webp","brochure_name":"master_in_aws_azure_cloud_technology","alt":"itvedant aws azure cloud technology brochure"},"data-science-and-ai":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"success-stories":{"image":"home_page.webp","brochure_name":"Itvedant_brochure","alt":"itvedant brochure"},"placements":{"image":"career-books.webp","brochure_name":"career_report","alt":"itvedant brochure"},"data-science-and-machine-learning":{"image":"executive-thumbnail.jpg","brochure_name":"executive","alt":"itvedant brochure"},"data-science-masterclass-for-executives":{"image":"home_page.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant brochure"},"python-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"java-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"data-analytics-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"data-science-course":{"image":"data-science-and-analytics.webp","brochure_name":"masters_in_data_science_with_ai_and_aws","alt":"itvedant data science and ai brochure"},"investment-banking-course":{"image":"investment-banking.webp","brochure_name":"investment_banking_with_ai","alt":"investment banking brochure"},"online-investment-banking-course":{"image":"investment-banking.webp","brochure_name":"ib","alt":"investment banking brochure"},"software-testing-course":{"image":"software-testing.webp","brochure_name":"master_in_software_testing_with_ai","alt":"software testing brochure"},"online-java-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_in_java","alt":"itvedant java full stack developer brochure"},"online-python-full-stack-development-course":{"image":"full-stack-course.webp","brochure_name":"master_certification_in_full_stack_development","alt":"itvedant full stack developer brochure"},"corporat ...
#   const custom_course = "data-science-and-ai";
#   const custom_page = "";
#   </script>
#   <!-- END: SMART POPUP -->
#   <!-- Global image load fallback: any image that fails to load shows placeholder (incl. dynamically added) -->
#   <script>
#    (function() {
#   var base = (typeof path !== 'undefined' && path) ? path : (typeof custom_base_url_link !== 'undefined' && custom_base_url_link ? custom_base_url_link : '');
#   var fallbackUrl = base ? (String(base).replace(/\/$/, '') + '/images/contact/blank.svg') : '/images/contact/blank.svg';
#   function applyFallbackToImg(img) {
#     if (img && img.nodeName === 'IMG' && !img.hasAttribute('onerror')) {
#       img.setAttribute('onerror', "this.onerror=null;this.src='" + fallbackUrl.replace(/'/g, "\\'") + "';");
#     }
#   }
#   function applyFallback() {
#     document.querySelectorAll('img').forEach(applyFallbackToImg);
#   }
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', function() {
#       applyFallback();
#       var observer = new MutationObserver(function(mutations) {
#         mutations.forEach(function(m) {
#           if (m.addedNodes && m.addedNodes.length) {
#             for (var i = 0; i < m.addedNodes.length; i++) {
#               var n = m.addedNodes[i];
#               if (n.nodeType === 1) {
#                 if (n.tagName === 'IMG') applyFallbackToImg(n);
#                 if (n.querySelectorAll) n.querySelectorAll('img').forEach(applyFallbackToImg);
#               }
#             }
#           }
#         });
#       });
#       observer.observe(document.body, { childList: true, subtree: true });
#     });
#   } else {
#     applyFallback();
#   }
# })();
#   </script>
#  </body>
# </html>
# <script>
#  (function() {
#     var currentPath = (window.location.pathname || '').toLowerCase();
#     if (currentPath.indexOf('/data-science-and-ai-in-nigeria') === -1 && currentPath.indexOf('/data-science-and-ai-in-kenya') === -1 && currentPath.indexOf('/data-science-and-ai-in-tanzania') === -1) return;
#     var customPopupImage = "";
#     var customPopupBrochureName = "";
#     if (!customPopupImage && !customPopupBrochureName) return;
#     var selector = '.trigger-custom-modal[data-modal-link="templates/popups/default/forms/popup-download-brochure.php"], .trigger-custom-modal[data-modal-link="/templates/popups/default/forms/popup-download-brochure.php"]';
#     var buttons = document.querySelectorAll(selector);
#     buttons.forEach(function(button) {
#       if (customPopupImage) button.setAttribute('data-custom-popup-image', customPopupImage);
#       if (customPopupBrochureName) button.setAttribute('data-custom-popup-brochure-name', customPopupBrochureName);
#     });
#   })();
# </script>
# <script type="application/ld+json">
#  {
#       "@context": "https://schema.org/",
#       "@type": "Product",
#       "name": "Data Science & Analytics with AI Course",
#       "image": "https://www.itvedant.com/images/location/thane1.webp",
#       "description": "An Industry-aligned Data Science & Analytics with AI course with 100% Job Guarantee !!",
#       "brand": {
#         "@type": "Brand",
#         "name": "Itvedant Education Pvt. Ltd"
#       },
#       "offers": {
#         "@type": "Offer",
#         "url": "https://www.itvedant.com/data-science-and-ai",
#         "priceCurrency": "INR",
#         "price": "0",
#         "priceValidUntil": "2040-01-01",
#         "availability": "https://schema.org/LimitedAvailability",
#         "itemCondition": "https://schema.org/NewCondition"
#       },
#       "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "4",
#         "bestRating": "5",
#         "worstRating": "0",
#         "ratingCount": "1",
#         "reviewCount": "1"
#       },
#       "review": {
#           "@type": "Review",
#           "name": "Ashwini Ingle",
#           "reviewBody": "Very nice teaching skills Cooperative faculties Asif sir was really helpful",
#           "reviewRating":
#           {
#             "@type": "Rating",
#             "ratingValue": "4",
#             "bestRating": "5",
#             "worstRating": "0"
#           },
#           "datePublished": "2023-03-11",
#           "author": { "@type": "Person", "name": "Ashwini Ingle" },
#           "publisher": { "@type": "Organization", "name": "Ashwini Ingle" }
#       }
#     }
# </script>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/index.html"

response = requests.get(url)

print("Status Code :", response.status_code)
print("Page Fetched Successfully")
# Out:
# Status Code : 200
# Page Fetched Successfully

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

train_numbers = soup.find_all(class_="train-number")
train_numbers
# Out:
# [<td class="train-number">12951</td>,
#  <td class="train-number">12952</td>,
#  <td class="train-number">12163</td>,
#  <td class="train-number">12301</td>,
#  <td class="train-number">12657</td>,
#  <td class="train-number">11301</td>,
#  <td class="train-number">12246</td>,
#  <td class="train-number">19019</td>,
#  <td class="train-number">22691</td>,
#  <td class="train-number">12621</td>]

# %%
train_numbers
# Out:
# [<td class="train-number">12951</td>,
#  <td class="train-number">12952</td>,
#  <td class="train-number">12163</td>,
#  <td class="train-number">12301</td>,
#  <td class="train-number">12657</td>,
#  <td class="train-number">11301</td>,
#  <td class="train-number">12246</td>,
#  <td class="train-number">19019</td>,
#  <td class="train-number">22691</td>,
#  <td class="train-number">12621</td>]

# %%
train_numbers.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 train_numbers.text
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for t in train_numbers:
    print(t.text)
# Out:
# 12951
# 12952
# 12163
# 12301
# 12657
# 11301
# 12246
# 19019
# 22691
# 12621

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

train_numbers = soup.find_all(class_="train-number")

print("Train Numbers on IndRail:")
print("=" * 100)
for item in train_numbers:
    print(item.get_text())
# Out:
# Train Numbers on IndRail:
# ====================================================================================================
# 12951
# 12952
# 12163
# 12301
# 12657
# 11301
# 12246
# 19019
# 22691
# 12621

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

train_numbers = soup.find_all(class_="train-number")

print("Train Numbers on IndRail:")
print("=" * 100)
for item in train_numbers:
    print(item.text)
# Out:
# Train Numbers on IndRail:
# ====================================================================================================
# 12951
# 12952
# 12163
# 12301
# 12657
# 11301
# 12246
# 19019
# 22691
# 12621

# %%
featured-trains-table

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")
idd =  soup.find_all(id="featured-trains-table")
for t in idd:
    print(t.text)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="train-schedule-table")
rows  = table.find("tbody").find_all("tr")

print("Train Schedule:")
print("=" * 60)

for row in rows:
    cells      = row.find_all("td")
    train_no   = cells[0].get_text()
    train_name = cells[1].get_text()
    from_stn   = cells[2].get_text()
    to_stn     = cells[3].get_text()
    departure  = cells[4].get_text()
    arrival    = cells[5].get_text()
    duration   = cells[6].get_text()
# Out:
# Train Schedule:
# ============================================================

# %%
cells
# Out:
# [<td class="train-number">12621</td>,
#  <td class="train-name">Tamil Nadu Express</td>,
#  <td>Delhi Junction (DLI)</td>,
#  <td>Chennai Central (MAS)</td>,
#  <td>22:30</td>,
#  <td>07:10 (+2)</td>,
#  <td>32h 40m</td>,
#  <td>Daily</td>,
#  <td>Superfast</td>,
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>]

# %%
train_no
# Out:
# '12621'

# %%
r = soup.find_all("div" , class_ = "table-wrapper")
r
# Out:
# [<div class="table-wrapper">
#  <table id="train-schedule-table">
#  <thead>
#  <tr>
#  <th>Train No.</th>
#  <th>Train Name</th>
#  <th>From</th>
#  <th>To</th>
#  <th>Departure</th>
#  <th>Arrival</th>
#  <th>Duration</th>
#  <th>Days</th>
#  <th>Type</th>
#  <th>Action</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr id="train-12951">
#  <td class="train-number">12951</td>
#  <td class="train-name">Mumbai Rajdhani Express</td>
#  <td>Mumbai Central (BCT)</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>17:00</td>
#  <td>08:35 (+1)</td>
#  <td>15h 35m</td>
#  <td>Daily</td>
#  <td>Rajdhani</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12952">
#  <td class="train-number">12952</td>
#  <td class="train-name">New Delhi Rajdhani Express</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>Mumbai Central (BCT)</td>
#  <td>16:55</td>
#  <td>08:15 (+1)</td>
#  <td>15h 20m</td>
#  <td>Daily</td>
#  <td>Rajdhani</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12163">
#  <td class="train-number">12163</td>
#  <td class="train-name">Chennai Superfast Express</td>
#  <td>Mumbai CST (CSTM)</td>
#  <td>Chennai Central (MAS)</td>
#  <td>23:45</td>
#  <td>03:30 (+2)</td>
#  <td>27h 45m</td>
#  <td>Mon, Thu, Sat</td>
#  <td>Superfast</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12301">
#  <td class="train-number">12301</td>
#  <td class="train-name">Howrah Rajdhani Express</td>
#  <td>Howrah (HWH)</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>14:05</td>
#  <td>09:55 (+1)</td>
#  <td>19h 50m</td>
#  <td>Daily</td>
#  <td>Rajdhani</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12657">
#  <td class="train-number">12657</td>
#  <td class="train-name">Bangalore Mail</td>
#  <td>Chennai Central (MAS)</td>
#  <td>Bangalore City (SBC)</td>
#  <td>22:00</td>
#  <td>05:30 (+1)</td>
#  <td>7h 30m</td>
#  <td>Daily</td>
#  <td>Mail</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-11301">
#  <td class="train-number">11301</td>
#  <td class="train-name">Udyan Express</td>
#  <td>Mumbai CST (CSTM)</td>
#  <td>Bangalore City (SBC)</td>
#  <td>08:05</td>
#  <td>11:35 (+1)</td>
#  <td>27h 30m</td>
#  <td>Daily</td>
#  <td>Express</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12246">
#  <td class="train-number">12246</td>
#  <td class="train-name">Yuva Express</td>
#  <td>Howrah (HWH)</td>
#  <td>Pune Junction (PUNE)</td>
#  <td>11:35</td>
#  <td>21:00 (+1)</td>
#  <td>33h 25m</td>
#  <td>Tue, Fri</td>
#  <td>Express</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-19019">
#  <td class="train-number">19019</td>
#  <td class="train-name">Dehradun Express</td>
#  <td>Ahmedabad Junction (ADI)</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>06:20</td>
#  <td>05:10 (+1)</td>
#  <td>22h 50m</td>
#  <td>Wed, Sun</td>
#  <td>Express</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-22691">
#  <td class="train-number">22691</td>
#  <td class="train-name">Rajdhani Express</td>
#  <td>Bangalore City (SBC)</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>20:00</td>
#  <td>05:30 (+2)</td>
#  <td>33h 30m</td>
#  <td>Mon, Wed, Fri</td>
#  <td>Rajdhani</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  <tr id="train-12621">
#  <td class="train-number">12621</td>
#  <td class="train-name">Tamil Nadu Express</td>
#  <td>Delhi Junction (DLI)</td>
#  <td>Chennai Central (MAS)</td>
#  <td>22:30</td>
#  <td>07:10 (+2)</td>
#  <td>32h 40m</td>
#  <td>Daily</td>
#  <td>Superfast</td>
#  <td><a href="booking.html"><button class="btn btn-outline" style="padding:6px 14px;font-size:12px;">Book</button></a></td>
#  </tr>
#  </tbody>
#  </table>
#  </div>]

# %%
r = soup.find_all("div" , class_ = "table-wrapper")
for h in r:
    print(h.text)
# Out:
# Train No.
# Train Name
# From
# To
# Departure
# Arrival
# Duration
# Days
# Type
# Action
#
#
#
#
# 12951
# Mumbai Rajdhani Express
# Mumbai Central (BCT)
# Delhi Junction (DLI)
# 17:00
# 08:35 (+1)
# 15h 35m
# Daily
# Rajdhani
# Book
#
#
# 12952
# New Delhi Rajdhani Express
# Delhi Junction (DLI)
# Mumbai Central (BCT)
# 16:55
# 08:15 (+1)
# 15h 20m
# Daily
# Rajdhani
# Book
#
#
# 12163
# Chennai Superfast Express
# Mumbai CST (CSTM)
# Chennai Central (MAS)
# 23:45
# 03:30 (+2)
# 27h 45m
# Mon, Thu, Sat
# Superfast
# Book
#
#
# 12301
# Howrah Rajdhani Express
# Howrah (HWH)
# Delhi Junction (DLI)
# 14:05
# 09:55 (+1)
# 19h 50m
# Daily
# Rajdhani
# Book
#
#
# 12657
# Bangalore Mail
# Chennai Central (MAS)
# Bangalore City (SBC)
# 22:00
# 05:30 (+1)
# 7h 30m
# Daily
# Mail
# Book
#
#
# 11301
# Udyan Express
# Mumbai CST (CSTM)
# Bangalore City (SBC)
# 08:05
# 11:35 (+1)
# 27h 30m
# Daily
# Express
# Book
#
#
# 12246
# Yuva Express
# Howrah (HWH)
# Pune Junction (PUNE)
# 11:35
# 21:00 (+1)
# 33h 25m
# Tue, Fri
# Express
# Book
#
#
# 19019
# Dehradun Express
# Ahmedabad Junction (ADI)
# Delhi Junction (DLI)
# 06:20
# 05:10 (+1)
# 22h 50m
# Wed, Sun
# Express
# Book
#
#
# 22691
# Rajdhani Express
# Bangalore City (SBC)
# Delhi Junction (DLI)
# 20:00
# 05:30 (+2)
# 33h 30m
# Mon, Wed, Fri
# Rajdhani
# Book
#
#
# 12621
# Tamil Nadu Express
# Delhi Junction (DLI)
# Chennai Central (MAS)
# 22:30
# 07:10 (+2)
# 32h 40m
# Daily
# Superfast
# Book

# %%
r = soup.find_all("div" , class_ = "table-wrapper")
for h in r:
    print(h.text.strip())
# Out:
# Train No.
# Train Name
# From
# To
# Departure
# Arrival
# Duration
# Days
# Type
# Action
#
#
#
#
# 12951
# Mumbai Rajdhani Express
# Mumbai Central (BCT)
# Delhi Junction (DLI)
# 17:00
# 08:35 (+1)
# 15h 35m
# Daily
# Rajdhani
# Book
#
#
# 12952
# New Delhi Rajdhani Express
# Delhi Junction (DLI)
# Mumbai Central (BCT)
# 16:55
# 08:15 (+1)
# 15h 20m
# Daily
# Rajdhani
# Book
#
#
# 12163
# Chennai Superfast Express
# Mumbai CST (CSTM)
# Chennai Central (MAS)
# 23:45
# 03:30 (+2)
# 27h 45m
# Mon, Thu, Sat
# Superfast
# Book
#
#
# 12301
# Howrah Rajdhani Express
# Howrah (HWH)
# Delhi Junction (DLI)
# 14:05
# 09:55 (+1)
# 19h 50m
# Daily
# Rajdhani
# Book
#
#
# 12657
# Bangalore Mail
# Chennai Central (MAS)
# Bangalore City (SBC)
# 22:00
# 05:30 (+1)
# 7h 30m
# Daily
# Mail
# Book
#
#
# 11301
# Udyan Express
# Mumbai CST (CSTM)
# Bangalore City (SBC)
# 08:05
# 11:35 (+1)
# 27h 30m
# Daily
# Express
# Book
#
#
# 12246
# Yuva Express
# Howrah (HWH)
# Pune Junction (PUNE)
# 11:35
# 21:00 (+1)
# 33h 25m
# Tue, Fri
# Express
# Book
#
#
# 19019
# Dehradun Express
# Ahmedabad Junction (ADI)
# Delhi Junction (DLI)
# 06:20
# 05:10 (+1)
# 22h 50m
# Wed, Sun
# Express
# Book
#
#
# 22691
# Rajdhani Express
# Bangalore City (SBC)
# Delhi Junction (DLI)
# 20:00
# 05:30 (+2)
# 33h 30m
# Mon, Wed, Fri
# Rajdhani
# Book
#
#
# 12621
# Tamil Nadu Express
# Delhi Junction (DLI)
# Chennai Central (MAS)
# 22:30
# 07:10 (+2)
# 32h 40m
# Daily
# Superfast
# Book

# %%
r = soup.find_all("div" , class_ = "table-wrapper")
we = []
for h in r:
    we.append(h.text.strip().split("\n"))

# %%
we[0][0]
# Out:
# 'Train No.'

# %%
we[0][1]
# Out:
# 'Train Name'

# %%
we[0][2]
# Out:
# 'From'

# %%
we[0][3]
# Out:
# 'To'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/trains.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="train-schedule-table")
rows  = table.find("tbody").find_all("tr")

print("Train Schedule:")
print("=" * 60)

for row in rows:
    cells      = row.find_all("td")
    train_no   = cells[0].get_text()
    train_name = cells[1].get_text()
    from_stn   = cells[2].get_text()
    to_stn     = cells[3].get_text()
    departure  = cells[4].get_text()
    arrival    = cells[5].get_text()
    duration   = cells[6].get_text()
# Out:
# Train Schedule:
# ============================================================

# %%
print(train_no, "|", train_name)
print("From :", from_stn, "-> To :", to_stn)
print("Departure :", departure, "| Arrival :", arrival, "| Duration :", duration)
print("-" * 60)
# Out:
# 12621 | Tamil Nadu Express
# From : Delhi Junction (DLI) -> To : Chennai Central (MAS)
# Departure : 22:30 | Arrival : 07:10 (+2) | Duration : 32h 40m
# ------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

url = "https://contentitvedant.github.io/Railway_Booking/passengers.html"

response = requests.get(url)
soup     = BeautifulSoup(response.text, "html.parser")

table = soup.find(id="passenger-records-table")
rows  = table.find("tbody").find_all("tr")

print("Passenger Records:")
print("=" * 60)

for row in rows:
    pnr  = row["data-pnr"]
    name = row.find(class_="passenger-name").get_text()
    date = row.find(class_="journey-date").get_text()
    cls  = row.find(class_="travel-class").get_text()
    seat = row.find(class_="seat-number").get_text()
    fare = row.find(class_="fare").get_text()
    
    print("PNR  :", pnr)
    print("Name :", name)
    print("Date :", date, "| Class :", cls, "| Seat :", seat, "| Fare : Rs.", fare)
    print("-" * 60)
# Out:
# Passenger Records:
# ============================================================
# PNR  : 43821756
# Name : Rahul Sharma
# Date : 2024-11-15 | Class : 3A | Seat : B4 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 67934521
# Name : Priya Menon
# Date : 2024-11-16 | Class : 2A | Seat : A12 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 81204763
# Name : Arjun Nair
# Date : 2024-11-17 | Class : SL | Seat : — | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 52983104
# Name : Sunita Rao
# Date : 2024-11-18 | Class : 2A | Seat : C7 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 39047682
# Name : Vikram Patel
# Date : 2024-11-20 | Class : 3A | Seat : D23 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 74512839
# Name : Kavya Iyer
# Date : 2024-11-19 | Class : SL | Seat : — | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 60183475
# Name : Aditya Joshi
# Date : 2024-11-22 | Class : 1A | Seat : A3 | Fare : Rs. 2170
# ------------------------------------------------------------
# PNR  : 95261847
# Name : Deepa Krishnan
# Date : 2024-11-21 | Class : 3A | Seat : B18 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 12873649
# Name : Mohan Das
# Date : 2024-11-15 | Class : 2A | Seat : A6 | Fare : Rs. 1220
# ------------------------------------------------------------
# PNR  : 48730261
# Name : Ananya Singh
# Date : 2024-11-23 | Class : SL | Seat : C31 | Fare : Rs. 420
# ------------------------------------------------------------
# PNR  : 33918274
# Name : Ravi Kumar
# Date : 2024-11-24 | Class : 3A | Seat : D9 | Fare : Rs. 880
# ------------------------------------------------------------
# PNR  : 76459013
# Name : Neha Gupta
# Date : 2024-11-25 | Class : 3A | Seat : B55 | Fare : Rs. 880
# ------------------------------------------------------------
